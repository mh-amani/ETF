# %% [markdown]
# #### Imports

# %%
project_root_dir = "../../../"

import os
work_dir = os.path.abspath(project_root_dir)

import sys
sys.path.append(project_root_dir)

import wandb
import re

import pandas as pd
from IPython.display import display, HTML
from functools import reduce

import numpy as np

from src.utils import evaluation_helpers
from src.datamodules import IEGenericOutputDataset

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
sns.set_style("ticks")
sns.set_palette("deep")

# %%
# %%html
# <style>
# .dataframe td {
#     white-space: nowrap;
# }
# </style>
# Out:
# <style>
# .dataframe td {
#     white-space: nowrap;
# }
# </style>

# %% [markdown]
# ## The Part to Update

# %%
run_name2wandb_path = {
 'v3_sdg_code_davinci_002_cw-genie_split-test_code_davinci_20_cm-free_lp-0.8': 'martinj96/SynthIE/2hlnoazf',
 'v3_rebel_cw-genie_split-test_20_cm-free_lp-0.8': 'martinj96/SynthIE/1w4cry91',
 'v3_sdg_code_davinci_002_cw-genie_split-test_code_davinci_20_cm-R-max_lp-0.8': 'martinj96/SynthIE/ht2eevgz',
 'v3_rebel_cw-genie_split-test_20_cm-R-max_lp-0.8': 'martinj96/SynthIE/ixojr0qq'
}

# Used for the process_results launcher
# print(" ".join(list(run_name2wandb_path.values())))

# %%
#### Which experiments to consider?

# model_id_wandb_run_path_pairs = [("R", "martinj96/SynthIE/izr0vgpw"), ("R+S", "martinj96/SynthIE/2f857wrl"), ("R", "martinj96/SynthIE/3274th6j"), ("R+S", "martinj96/SynthIE/runs/22djwbxk")]
model_id_wandb_run_path_pairs = [("R", wandb_path) if run_name.startswith("v2") else ("R+S", wandb_path) for run_name, wandb_path in run_name2wandb_path.items()][::-1]

#### What to report?

PRESENT_QUANTITATIVE_RESULTS = True
PRESENT_QUALITATIVE_RESULTS = True


# ~~~ Qauntitative results ~~~
metrics = ["triplet_set_precision", "triplet_set_recall", "triplet_set_f1"]
# Used for the confidence interval retrieval from the results.json file
n_bootstrap_samples = 50  # Set to None to present only the corpus level metric (without confidence intervals)
confidence_level = 0.95

metric_name2label = {"triplet_set_precision": "P", "triplet_set_recall": "R", "triplet_set_f1": "F1"}
dataset_name2dataset_label = {"rebel": "REBEL", "sdg_code_davinci_002": "[SDG] Code Davinci"}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# ~~~ Qualitative results ~~~
n_samples = 20
n_predictions_to_show = 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ##### Define Experiment ID

# %%
# ~~~ Optional ~~~~
def retrieve_constraint_module_id(hydra_config):
    cm_cfg = hydra_config['model']['constraint_module']

    if cm_cfg == None or cm_cfg == 'None':
        return "free"

    identifier2label = {'genie': 'R-max'}
    return identifier2label.get(cm_cfg['identifier'], cm_cfg['identifier'])

def retrieve_lenght_penalty(hydra_config):
    return hydra_config['model']['hparams_overrides']['inference']['hf_generation_params']['length_penalty']
# ~~~~~~~~~~~~~~~~~~

# The names of these functions should not change    
def get_exp_id(model_id, hydra_config):
    return f"{model_id} -- ({retrieve_constraint_module_id(hydra_config)}) lp_{retrieve_lenght_penalty(hydra_config)} [{dataset_name2dataset_label[retrieve_dataset_name(hydra_config)]}]"

def retrieve_dataset_name(hydra_config):
    return hydra_config['datamodule']['name']

results_df_field2getter = {"LP": retrieve_lenght_penalty, "Constraint": retrieve_constraint_module_id}
barplot_hue_ordering = ['Model', 'LP', 'Constraint']
results_ordering = barplot_hue_ordering

# %% [markdown]
# ## Main Part

# %%
wandb_configs = {}
hydra_configs = {}
abs_exp_dirs = {}

output_datasets = {}
results = {}

exp_id2wandb_run_path = {}
exp_id2model_id = {}

for model_id, wandb_run_path in model_id_wandb_run_path_pairs:
    api = wandb.Api()
    run = api.run(wandb_run_path)
    wandb_config, hydra_config, abs_exp_dir = evaluation_helpers.prepare_data_for_experiment(wandb_run_path, work_dir, print)
    exp_id = get_exp_id(model_id, hydra_config)
    exp_id2wandb_run_path[exp_id] = wandb_run_path
    exp_id2model_id[exp_id] = model_id

    wandb_configs[exp_id], hydra_configs[exp_id], abs_exp_dirs[exp_id] = wandb_config, hydra_config, abs_exp_dir

    # Load predictions data
    data_dir = os.path.join(abs_exp_dirs[exp_id], "predictions")
    output_datasets[exp_id] = IEGenericOutputDataset(data_dir=data_dir, seed=123)

    # Load existing results data
    results[exp_id] = evaluation_helpers.Results(abs_exp_dirs[exp_id])

exp_ids = list(results.keys())
# Out:
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/v3_rebel_cw-genie_split-test_20_cm-R-max_lp-0.8/2023-01-09_21-33-44
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/v3_sdg_code_davinci_002_cw-genie_split-test_code_davinci_20_cm-R-max_lp-0.8/2023-01-09_21-39-34
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/v3_rebel_cw-genie_split-test_20_cm-free_lp-0.8/2023-01-09_21-54-58
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/v3_sdg_code_davinci_002_cw-genie_split-test_code_davinci_20_cm-free_lp-0.8/2023-01-09_21-56-16
# Loading the existing results

# %%
if PRESENT_QUANTITATIVE_RESULTS:
    metric_label = [metric_name2label[metric_id] for metric_id in metrics]

    # Retrieve information
    results_dfs = []
    for exp_id in exp_id2wandb_run_path.keys():
        curr_results = results[exp_id]
        
        if n_bootstrap_samples is None:
            y = [curr_results.get_corpus_level_metric(metric_id) for metric_id in metrics]
            yerr = None
        else:
            y = []
            yerr = []
            for metric_id in metrics:
                ci = curr_results.get_ci(metric_id, confidence_level, n_bootstrap_samples)
                y.append(ci['mean'])
                yerr.append((ci['mean'] - ci['lower'], ci['upper'] - ci['mean']))

            yerr = np.array(yerr).T

        # create a datataframe
        df = pd.DataFrame({'Metric': metric_label, 'Score': y, 'ci_score_lower': yerr[0, :], 'ci_score_upper': yerr[1, :]})
        
        # required fields
        df['Exp_ID'] = [exp_id] * df.shape[0]
        df['Dataset'] = [retrieve_dataset_name(hydra_configs[exp_id])] * df.shape[0]
        df['Model'] = [exp_id2model_id[exp_id]] * df.shape[0]

        # optional fields
        if results_df_field2getter is not None:
            for field_name, getter in results_df_field2getter.items():
                df[field_name] = [getter(hydra_configs[exp_id])] * df.shape[0]
        results_dfs.append(df)

    results_df = pd.concat(results_dfs, axis=0)
    
    # Massage the data
    dataset_names = results_df['Dataset'].unique()

    per_dataset_results_long = {}
    per_dataset_results_wide = {}

    per_dataset_results_ci_lower = {}
    per_dataset_results_ci_upper = {}

    for dataset_name in dataset_names:
        dataset_long_df = results_df[results_df['Dataset'] == dataset_name].copy()
        # set the error term to the average of the empirical lower and upper confidence interval delta
        # dataset_long_df['Error'] = ((dataset_long_df['ci_score_lower'] + dataset_long_df['ci_score_upper']) / 2)
        # dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + ' ± ' + (dataset_long_df['Error']*100).round(2).astype(str)
        dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + " [" + ((dataset_long_df['Score']-dataset_long_df['ci_score_lower'])*100).round(2).astype(str) + ", " + ((dataset_long_df['Score'] + dataset_long_df['ci_score_upper'])*100).round(2).astype(str) + "]"
        per_dataset_results_long[dataset_name] = dataset_long_df

        pivot_index = ['Model']
        if results_df_field2getter is not None:
            pivot_index.extend(list(results_df_field2getter.keys()))
        dataset_wide_df = dataset_long_df.pivot_table(index=pivot_index, columns='Metric', values='Score_with_ci', aggfunc=lambda x: ' '.join(x))
        dataset_wide_df = dataset_wide_df[['P', 'R', 'F1']]
        per_dataset_results_wide[dataset_name] = dataset_wide_df

    results_wide_df = pd.concat(per_dataset_results_wide.values(), keys=per_dataset_results_wide.keys(), names=['Dataset'], axis=1)
    results_wide_df = results_wide_df.sort_index(axis=0, level=results_ordering)
    results_wide_df.columns = pd.MultiIndex.from_tuples([(dataset_name2dataset_label[dataset_name], metric) for dataset_name, metric in results_wide_df.columns.values], names=['Dataset', f'Metric [{int(confidence_level*100)}% CI]'])
    
    display(results_wide_df)
# Out:
# Dataset                             REBEL                        \
# Metric [95% CI]                         P                     R
# Model LP  Constraint
# R+S   0.8 R-max        9.43 [3.84, 13.85]  22.33 [11.42, 31.82]
#           free        11.75 [5.37, 17.63]   24.44 [13.63, 37.5]
#
# Dataset                                     [SDG] Code Davinci  \
# Metric [95% CI]                       F1                     P
# Model LP  Constraint
# R+S   0.8 R-max       13.2 [5.74, 18.83]  87.55 [79.59, 92.64]
#           free        15.8 [7.82, 23.58]  78.99 [63.32, 88.61]
#
# Dataset
# Metric [95% CI]                          R                    F1
# Model LP  Constraint
# R+S   0.8 R-max       62.14 [56.38, 70.21]  72.63 [66.67, 79.37]
#           free        55.19 [41.96, 66.11]  64.93 [50.38, 75.06]

# %%
# Figure for the table above
if PRESENT_QUANTITATIVE_RESULTS:
    capsize = 0

    # get a subplot for each dataset
    figsize = (10, 7 * len(dataset_names))
    fig, axes = plt.subplots(len(dataset_names), 1, figsize=figsize, sharex=True, sharey=True)
    
    if len(dataset_names) == 1:
        axes = [axes]

    for ax, dataset_name in zip(axes, dataset_names):
        dataset_results_long_df = per_dataset_results_long[dataset_name]
        # sort the dataframe accoring to the Constraint, Model and LP
        if barplot_hue_ordering is not None:
            dataset_results_long_df = dataset_results_long_df.sort_values(by=barplot_hue_ordering)
        dataset_results_long_df.reset_index(inplace=True, drop=True)

        hue_order = dataset_results_long_df['Exp_ID'].drop_duplicates().values.tolist()
        order = ['P', 'R', 'F1']
        sns.barplot(ax=ax, data=dataset_results_long_df, x='Metric', y="Score", hue='Exp_ID', edgecolor="black", palette='deep', order=order, hue_order=hue_order)

        ax.set_title(dataset_name2dataset_label[dataset_name])
        ax.set_ylabel("Score")
        ax.set_ylim(0,1)
        if ax != axes[0]:
            ax.set_xlabel("Metric")
        else:
            ax.set_xlabel("")

        # make the legend a bit more compact and remove the box around the legend
        # handles, labels = ax.get_legend_handles_labels()
        ax.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1, frameon=False)

        if 'ci_score_lower' in dataset_results_long_df.columns:
            x_coords = [p.get_x() + 0.5 * p.get_width() for p in ax.patches]
            y_coords = [p.get_height() for p in ax.patches]

            dataset_results_long_df.Exp_ID = pd.Categorical(dataset_results_long_df.Exp_ID, categories=hue_order, ordered=True)
            dataset_results_long_df.Metric = pd.Categorical(dataset_results_long_df.Metric, categories=order, ordered=True)
            error = np.stack([dataset_results_long_df.sort_values(by=['Exp_ID', 'Metric'])['ci_score_lower'].values, dataset_results_long_df.sort_values(by=['Exp_ID', 'Metric'])['ci_score_upper'].values])
            ax.errorbar(x=x_coords, y=y_coords, yerr=error, fmt="none", color="black", capsize=capsize, zorder=10000)

# %%
def get_predictions_df(exp_ids):
        random_ids = None

        pred_dfs = []

        for exp_id in exp_ids:
            output_dataset = output_datasets[exp_id]

            
            if random_ids is None:
                random_indices = np.random.RandomState(seed).choice(len(output_dataset),  min([n_samples, len(output_dataset)]), replace=False)
                random_ids = set([output_dataset.data[i]['id'] for i in random_indices])

            random_sample = [output_dataset.data[i] for i in random_indices if output_dataset.data[i]['id'] in random_ids]

            ids = [sample['id'] for sample in random_sample]
            inputs = [sample['input'] for sample in random_sample]
            targets = [sample['target'] for sample in random_sample]
            predictions = [sample['prediction'][0] if n_predictions_to_show == 1 else sample['prediction'][:n_predictions_to_show] for sample in random_sample]

            df = pd.DataFrame(list(zip(ids, inputs, targets, predictions)), columns=['id', 'input', 'target', f'prediction_{exp_id}'])
            pred_dfs.append(df)

        predictions_df = reduce(lambda  left,right: pd.merge(left,right,on=['id', 'input', 'target'], how='inner', ), pred_dfs)
        predictions_df.sort_values(by=['id'], inplace=True)
        assert(predictions_df.shape[0] == len(random_ids))
        return predictions_df


def wrap_df_text(df, input_max_col):
    tdf = df.copy()
    tdf['input'] = tdf['input'].str.wrap(input_max_col)
    tdf['target'] = tdf['target'].str.replace("\[e\]|\[et\]", "[e]\\n", regex=True)

    for col in tdf.columns:
        if col.startswith("prediction"):
            if type(tdf[col][0]) == str:
                tdf[col] = tdf[col].str.replace("\[e\]|\[et\]", "[e]\\n", regex=True)
            else:
                tdf[col] = tdf[col].apply(lambda x: "\\n".join([re.sub("\[e\]|\[et\]", "[e]\\n", p) for p in x]))

    display(HTML(tdf.to_html().replace("\\n","<br>")))


if PRESENT_QUALITATIVE_RESULTS:
    seed = 123

    # get the dataset_name for each experiment
    dataset_names = list([retrieve_dataset_name(hydra_configs[exp_id]) for exp_id in exp_ids])

    for dataset_name in set(dataset_names):
        print(f"~~~~ {dataset_name2dataset_label[dataset_name]} ~~~~")
        exp_ids_to_visualize = [exp_id for exp_id, exp_dataset_name in zip(exp_ids, dataset_names) if exp_dataset_name  == dataset_name]
        print(exp_ids_to_visualize)
        predictions_df = get_predictions_df(exp_ids_to_visualize)

        with pd.option_context('display.max_rows', None, 'display.max_columns', None, "display.expand_frame_repr", False, 'display.max_colwidth', None, 'display.width', None):        
            wrap_df_text(predictions_df, 50)
# Out:
# ~~~~ [SDG] Code Davinci ~~~~
# ['R+S -- (R-max) lp_0.8 [[SDG] Code Davinci]', 'R+S -- (free) lp_0.8 [[SDG] Code Davinci]']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>input</th>
#       <th>target</th>
#       <th>prediction_R+S -- (R-max) lp_0.8 [[SDG] Code Davinci]</th>
#       <th>prediction_R+S -- (free) lp_0.8 [[SDG] Code Davinci]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>29248</td>
#       <td>Vanessa Ferlito is an American actress. She is a<br>vegetarian and writes in English.</td>
#       <td>[s] Vanessa_Ferlito [r] lifestyle [o] Vegetarianism [e]<br> [s] Vanessa_Ferlito [r] writing language [o] English_language [e]<br> [s] Vanessa_Ferlito [r] instance of [o] Human [e]<br> [s] Vanessa_Ferlito [r] country of citizenship [o] United_States [e]<br></td>
#       <td>[s] Vanessa_Ferlito [r] lifestyle [o] Vegetarianism [e]<br> [s] Vanessa_Ferlito [r] writing language [o] English_language [e]<br> [s] Vanessa_Ferlito [r] country of citizenship [o] United_States [e]<br></td>
#       <td>[s] Vanessa_Ferlito [r] lifestyle [o] Vegetarianism [e]<br> [s] Vanessa_Ferlito [r] writing language [o] English_language [e]<br> [s] Vanessa_Ferlito [r] country of citizenship [o] United_States [e]<br></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>80279</td>
#       <td>Superhot is a single-player video game developed<br>and published by Polish studio Superhot Team and<br>released in 2016. The game was released for<br>Microsoft Windows, OS X, and Linux in February<br>2016, and for the Xbox One in May 2016. The game<br>is currently slated for release on the PlayStation<br>VR headset.</td>
#       <td>[s] Superhot [r] output method [o] PlayStation_VR [e]<br> [s] Superhot [r] distribution format [o] Digital_distribution [e]<br> [s] Superhot [r] game mode [o] Single-player_video_game [e]<br> [s] Superhot [r] business model [o] Crowdfunding [e]<br> [s] Superhot [r] platform [o] PlayStation_4 [e]<br> [s] Superhot [r] country of origin [o] Poland [e]<br> [s] PlayStation_VR [r] manufacturer [o] Sony [e]<br></td>
#       <td>[s] Superhot [r] output method [o] PlayStation_VR [e]<br> [s] Superhot [r] game mode [o] Single-player_video_game [e]<br> [s] Superhot [r] country of origin [o] Poland [e]<br></td>
#       <td>[s] Superhot [r] output method [o] PlayStation_VR [e]<br> [s] Superhot [r] game mode [o] Single-player_video_game [e]<br> [s] Superhot [r] language of work or name [o] Polish_language [e]<br> [s] Superhot [r] country of origin [o] Poland [e]<br></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>123789</td>
#       <td>Tinoco was a Brazilian footballer who played as a<br>midfielder for CR Vasco da Gama. He was selected<br>to play for the Brazil national football team in<br>the 1934 FIFA World Cup.</td>
#       <td>[s] Tinoco_(Brazilian_footballer) [r] position played on team / speciality [o] Midfielder [e]<br> [s] Tinoco_(Brazilian_footballer) [r] member of sports team [o] CR_Vasco_da_Gama [e]<br> [s] Tinoco_(Brazilian_footballer) [r] country for sport [o] Brazil [e]<br> [s] Tinoco_(Brazilian_footballer) [r] participant in [o] 1934_FIFA_World_Cup [e]<br> [s] Tinoco_(Brazilian_footballer) [r] sport [o] Association_football [e]<br> [s] Tinoco_(Brazilian_footballer) [r] member of sports team [o] Brazil_national_football_team [e]<br> [s] CR_Vasco_da_Gama [r] official color or colors [o] Black [e]<br></td>
#       <td>[s] Tinoco_(Brazilian_footballer) [r] position played on team / speciality [o] Midfielder [e]<br> [s] Tinoco_(Brazilian_footballer) [r] participant in [o] 1934_FIFA_World_Cup [e]<br> [s] Tinoco_(Brazilian_footballer) [r] country for sport [o] Brazil [e]<br> [s] Tinoco_(Brazilian_footballer) [r] member of sports team [o] CR_Vasco_da_Gama [e]<br> [s] Midfielder [r] sport [o] Association_football [e]<br></td>
#       <td>[s] Tinoco [r] country for sport [o] Brazil [e]<br> [s] Tinoco [r] position played on team / speciality [o] Midfielder [e]<br> [s] Tinoco [r] participant in [o] 1934_FIFA_World_Cup [e]<br> [s] Tinoco [r] member of sports team [o] CR_Vasco_da_Gama [e]<br></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>133203</td>
#       <td>Verlus is a commune in France. It is bordered by<br>Moncla, Portet, and Projan. It is located in the<br>UTC+02:00 and UTC+01:00 time zones.</td>
#       <td>[s] Verlus [r] shares border with [o] Moncla [e]<br> [s] Verlus [r] shares border with [o] Portet [e]<br> [s] Verlus [r] shares border with [o] Projan [e]<br> [s] Verlus [r] located in time zone [o] UTC+02:00 [e]<br> [s] Verlus [r] located in time zone [o] UTC+01:00 [e]<br> [s] Moncla [r] country [o] France [e]<br></td>
#       <td>[s] Verlus [r] shares border with [o] Moncla [e]<br> [s] Verlus [r] shares border with [o] Portet [e]<br> [s] Verlus [r] shares border with [o] Projan [e]<br> [s] Verlus [r] located in time zone [o] UTC+02:00 [e]<br> [s] Verlus [r] located in time zone [o] UTC+01:00 [e]<br></td>
#       <td>[s] Verlus [r] shares border with [o] Moncla [e]<br> [s] Verlus [r] shares border with [o] Portet [e]<br> [s] Verlus [r] shares border with [o] Projan [e]<br> [s] Verlus [r] located in time zone [o] UTC+02:00 [e]<br> [s] Verlus [r] located in time zone [o] UTC+01:00 [e]<br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>138498</td>
#       <td>Makat District is an administrative district of<br>Atyrau Region, Kazakhstan. It is located in the<br>north-east of the region, and its administrative<br>centre is the town of Makat.</td>
#       <td>[s] Makat_District [r] located in the administrative territorial entity [o] Atyrau_Region [e]<br> [s] Makat_District [r] capital [o] Makat [e]<br> [s] Makat_District [r] country [o] Kazakhstan [e]<br> [s] Makat_District [r] instance of [o] Districts_of_Kazakhstan [e]<br> [s] Atyrau_Region [r] capital [o] Atyrau [e]<br> [s] Makat [r] capital of [o] Makat_District [e]<br></td>
#       <td>[s] Makat_District [r] located in the administrative territorial entity [o] Atyrau_Region [e]<br> [s] Makat_District [r] country [o] Kazakhstan [e]<br> [s] Makat_District [r] instance of [o] Districts_of_Kazakhstan [e]<br> [s] Atyrau_Region [r] capital [o] Atyrau [e]<br></td>
#       <td>[s] Makat_District [r] capital [o] Makat,_Kazakhstan [e]<br> [s] Makat_District [r] located in the administrative territorial entity [o] Atyrau_Region [e]<br> [s] Makat_District [r] country [o] Kazakhstan [e]<br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>223443</td>
#       <td>Marcellin Champagnat was a French Roman Catholic<br>Marist Brother and saint. He was born in Marlhes,<br>France.</td>
#       <td>[s] Marcellin_Champagnat [r] canonization status [o] Saint [e]<br> [s] Marcellin_Champagnat [r] religious order [o] Society_of_Mary_(Marists) [e]<br> [s] Marcellin_Champagnat [r] place of birth [o] Marlhes [e]<br> [s] Marcellin_Champagnat [r] given name [o] Joseph [e]<br> [s] Marcellin_Champagnat [r] religious order [o] Marist_Brothers [e]<br> [s] Marlhes [r] located in the administrative territorial entity [o] Loire_(department) [e]<br></td>
#       <td>[s] Marcellin_Champagnat [r] canonization status [o] Saint [e]<br> [s] Marcellin_Champagnat [r] religion [o] Catholic_Church [e]<br> [s] Marcellin_Champagnat [r] place of birth [o] Marlhes [e]<br> [s] Marcellin_Champagnat [r] country of citizenship [o] France [e]<br></td>
#       <td>[s] Marcellin_Champagnat [r] canonization status [o] Saint [e]<br> [s] Marcellin_Champagnat [r] religion [o] Catholic_Church [e]<br> [s] Marcellin_Champagnat [r] place of birth [o] Marlhes [e]<br> [s] Marcellin_Champagnat [r] country of citizenship [o] France [e]<br></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>368604</td>
#       <td>Nicolas Baudin Island is an island in the Great<br>Australian Bight off the coast of South Australia.<br>The island is part of Australia and is located in<br>the administrative territory of South Australia.<br>The Great Australian Bight is a bay off the coast<br>of Australia and the Johanna River flows into it.</td>
#       <td>[s] Nicolas_Baudin_Island [r] located in or next to body of water [o] Great_Australian_Bight [e]<br> [s
# ~~~~ REBEL ~~~~
# ['R+S -- (R-max) lp_0.8 [REBEL]', 'R+S -- (free) lp_0.8 [REBEL]']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>input</th>
#       <th>target</th>
#       <th>prediction_R+S -- (R-max) lp_0.8 [REBEL]</th>
#       <th>prediction_R+S -- (free) lp_0.8 [REBEL]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8</th>
#       <td>1750</td>
#       <td>Google Reader was an RSS/Atom feed aggregator<br>operated by Google.</td>
#       <td>[s] Google_Reader [r] instance of [o] News_aggregator [e]<br></td>
#       <td>[s] Google_Reader [r] use [o] News_aggregator [e]<br> [s] Google_Reader [r] operator [o] Google [e]<br></td>
#       <td>[s] Google_Reader [r] uses [o] RSS/Atom [e]<br> [s] Google_Reader [r] operator [o] Google [e]<br></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>5146</td>
#       <td>Described by Dlussky and Putyatina in 2014, the<br>fossils were found in Radoboj in Croatia.</td>
#       <td>[s] Radoboj [r] country [o] Croatia [e]<br></td>
#       <td>[s] Radoboj [r] located in time zone [o] UTC+01:00 [e]<br> [s] Radoboj [r] described by source [o] Brockhaus_and_Efron_Encyclopedic_Dictionary [e]<br> [s] Radoboj [r] country [o] Croatia [e]<br> [s] Radoboj [r] located in time zone [o] UTC+02:00 [e]<br> [s] UTC+01:00 [r] said to be the same as [o] Central_European_Time [e]<br> [s] Brockhaus_and_Efron_Encyclopedic_Dictionary [r] copyright status [o] Public_domain [e]<br></td>
#       <td>[s] Fossil [r] location of discovery [o] Radoboj [e]<br> [s] Fossil [r] described by source [o] Dlussky [e]<br> [s] Fossil [r] described by source [o] Putyatina [e]<br> [s] Radoboj [r] country [o] Croatia [e]<br></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>5990</td>
#       <td>Bak So-ra (Hangul: 박소라) is a South Korean voice<br>actress who joined the Munhwa Broadcasting<br>Corporation's voice acting division in 1995.</td>
#       <td>[s] Munhwa_Broadcasting_Corporation [r] country [o] South_Korea [e]<br></td>
#       <td>[s] Bak_So-ra [r] family name [o] Kim_(Korean_surname) [e]<br> [s] Bak_So-ra [r] languages spoken, written or signed [o] Korean_language [e]<br> [s] Bak_So-ra [r] employer [o] Munhwa_Broadcasting_Corporation [e]<br></td>
#       <td>[s] Bak_So-ra [r] family name [o] Kim_(Korean_surname) [e]<br> [s] Bak_So-ra [r] languages spoken, written or signed [o] Korean_language [e]<br> [s] Bak_So-ra [r] employer [o] Munhwa_Broadcasting_Corporation [e]<br></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>12999</td>
#       <td>Manzanares District is one of fifteen districts of<br>the province Concepción in Peru.</td>
#       <td>[s] Manzanares_District [r] country [o] Peru [e]<br> [s] Districts_of_Peru [r] country [o] Peru [e]<br> [s] Concepción_Province,_Peru [r] country [o] Peru [e]<br></td>
#       <td>[s] Manzanares_District [r] located in the administrative territorial entity [o] Concepción_Province,_Peru [e]<br> [s] Manzanares_District [r] country [o] Peru [e]<br> [s] Manzanares_District [r] instance of [o] Districts_of_Peru [e]<br></td>
#       <td>[s] Manzanares_District [r] located in the administrative territorial entity [o] Concepción_Province,_Peru [e]<br> [s] Manzanares_District [r] country [o] Peru [e]<br> [s] Manzanares_District [r] instance of [o] Districts_of_Peru [e]<br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15597</td>
#       <td>Mysłakowice () is a village in Jelenia Góra<br>County, Lower Silesian Voivodeship, in south-<br>western Poland.</td>
#       <td>[s] Karkonosze_County [r] country [o] Poland [e]<br> [s] Lower_Silesian_Voivodeship [r] country [o] Poland [e]<br></td>
#       <td>[s] Mysakowice [r] located in time zone [o] UTC+01:00 [e]<br> [s] Mysakowice [r] located in time zone [o] UTC+02:00 [e]<br> [s] Mysakowice [r] country [o] Poland [e]<br> [s] Mysakowice [r] located in the administrative territorial entity [o] Lower_Silesian_Voivodeship [e]<br> [s] UTC+01:00 [r] said to be the same as [o] Central_European_Time [e]<br></td>
#       <td>[s] Mysakowice [r] located in time zone [o] UTC+02:00 [e]<br> [s] Mysakowice [r] located in time zone [o] UTC+01:00 [e]<br> [s] Mysakowice [r] country [o] Poland [e]<br> [s] Mysakowice [r] located in the administrative territorial entity [o] Jelenia_Góra_County [e]<br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>22095</td>
#       <td>Edathanattukara or Kottappalla is a town in<br>Palakkad District, Kerala, India.</td>
#       <td>[s] Palakkad_district [r] country [o] India [e]<br> [s] Kerala [r] country [o] India [e]<br></td>
#       <td>[s] Edathanattukara [r] located in the administrative territorial entity [o] Palakkad_district [e]<br> [s] Edathanattukara [r] country [o] India [e]<br> [s] Palakkad_district [r] capital [o] Palakkad [e]<br></td>
#       <td>[s] Edathanattukara [r] located in the administrative territorial entity [o] Palakkad_district [e]<br> [s] Edathanattukara [r] country [o] India [e]<br> [s] Palakkad_district [r] capital [o] Palakkad [e]<br></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>24970</td>
#       <td>Bag Balm is a salve developed in 1899 to soothe<br>irritation on cows' udders after milking.</td>
#       <td>[s] Bag_Balm [r] instance of [o] Salve [e]<br></td>
#       <td>[s] Bag_Balm [r] natural product of taxon [o] Cattle [e]<br> [s] Bag_Balm [r] described by source [o] Brockhaus_and_Efron_Encyclopedic_Dictionary [e]<br> [s] Bag_Balm [r] use [o] Salve [e]<br></td>
#       <td>[s] Bag_Balm [r] natural product of taxon [o] Cattle [e]<br> [s] Bag_Balm [r] use [o] Salve [e]<br> [s] Bag_Balm [r] instance of [o] Medication [e]<br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>27402</td>
#       <td>The Bürgergemeinde (also Burgergemeinde,<br>Ortsgemeinde, Ortsbürgergemeinde, Tagwen,<br>bourgeoisie, commune bourgeoise, vischnanca<br>burgaisa, ) is a statutory corporation in public<br>law in Switzerland.</td>
#       <td>[s] Bürgergemeinde [r] instance of [o] Statutory_corporation [e]<br> [s] Bürgergemeinde [r] country [o] Switzerland [e]<br> [s] Statutory_corporation [r] part of [o] Public_law [e]<br></td>
#       <td>[s] Bürgergemeinde [r] applies to jurisdiction [o] Switzerland [e]<br> [s] Bürgergemeinde [r] subclass of [o] Statutory_corporation [e]<br> [s] Bürgergemeinde [r] described by source [o] Brockhaus_and_Efron_Encyclopedic_Dictionary [e]<br></td>
#       <td>[s] Bürgergemeinde [r] main regulatory text [o] Strafgesetzbuch [e]<br> [s] Bürgergemeinde [r] subclass of [o] Statutory_corporation [e]<br> [s] Bürgergemeinde [r] country [o] Switzerland [e]<br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>28626</td>
#       <td>The Armed Forces Institute of Cardiology (, or<br>AFIC) also known as the National Institute of<br>Heart Diseases or NIHD is a government and<br>military cardiac hospital located in Rawalpindi<br>Cantonment, Punjab, Pakistan.</td>
#       <td>[s] Armed_Forces_Institute_of_Cardiology [r] instance of [o] Hospital [e]<br></td>
#       <td>[s] Armed_Forces_Institute_of_Cardiology [r] located in the administrative territorial entity [o] Rawalpindi_Cantonment [e]<br> [s] Armed_Forces_Institute_of_Cardiology [r] country [o] Pakistan [e]<br> [s] Armed_Forces_Institute_of_Cardiology [r] instance of [o] Hospital [e]<br></td>
#       <td>[s] Armed_Forces_Institute_of_Cardiology [r] located in the administrative territorial entity [o] Rawalpindi_Cantonment [e]<br> [s] Armed_Forces_Institute_of_Cardiology [r] country [o] Pakistan [e]<br> [s] Armed_Forces_Institute_of_Cardiology [r] instance of [o] Hospital [e]<br></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>32175</td>
#       <td>Skinnerapuram is a village in West Godavari<br>district in the state of Andhra Pradesh in India.</td>
#       <td>[s] Skinnerapuram [r] country [o] India [e]<br> [s] West_Godavari_district [r] country [o] India [e]<br> [s] Andhra_Pradesh [r] country [o] India [e]<br></td>
#       <td>[s] Skinnerapuram [r] located in the administrative territorial entity [o] West_Godavari_district [e]<br> [s] Skinnerapuram [r] country [o] India [e]<br> [s] Skinnerapuram [r] instance of [o] Human_settlement [
