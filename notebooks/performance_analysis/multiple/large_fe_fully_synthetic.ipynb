# %% [markdown]
# #### Imports

# %%
project_root_dir = "../../../"

import os
work_dir = os.path.abspath(project_root_dir)

import sys
sys.path.append(project_root_dir)

import wandb
import re

import pandas as pd
from IPython.display import display, HTML
from functools import reduce

import numpy as np

from src.utils import evaluation_helpers
from src.datamodules import IEGenericOutputDataset

import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint

sns.set_theme(style="whitegrid")
sns.set_style("ticks")
sns.set_palette("deep")

# %%
# %%html
# <style>
# .dataframe td {
#     white-space: nowrap;
# }
# </style>
# Out:
# <style>
# .dataframe td {
#     white-space: nowrap;
# }
# </style>

# %% [markdown]
# ## The Part to Update

# %%
# Helper for getting the desired wandb run names and wandb paths
# epfl-dlab/SynthIE/1rgxe7t7
api = wandb.Api()
entity, project = "epfl-dlab", "SynthIE"  # set to your entity and project 
runs = api.runs(entity + "/" + project) 
run_name2wandb_path = {}
for run in runs:
    if run.name.startswith('inf_fe_fully_synthetic_gcp_large') and "constraint-free" not in run.name:
        run_name2wandb_path[run.name] = f"{entity}/{project}/{run.id}"
pprint(run_name2wandb_path)
# Out:
# {'inf_fe_fully_synthetic_gcp_large_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.6': 'epfl-dlab/SynthIE/1l771cuv',
#  'inf_fe_fully_synthetic_gcp_large_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.8': 'epfl-dlab/SynthIE/26x7v8sl',
#  'inf_fe_fully_synthetic_gcp_large_last_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.6': 'epfl-dlab/SynthIE/10simjkz',
#  'inf_fe_fully_synthetic_gcp_large_last_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.8': 'epfl-dlab/SynthIE/1ot3pbs0',
#  'inf_fe_fully_synthetic_gcp_large_last_datamodule-sdg_code_davinci_002_world-genie_t5_tokenizeable_split-test_small_ordered_constraint-R-max-T5_lp-0.8': 'epfl-dlab/SynthIE/w2qbchl7',
#  'inf_fe_fully_synthetic_gcp_large_last_datamodule-sdg_text_davinci_003_world-genie_t5_tokenizeable_split-test_small_ordered_constraint-R-max-T5_lp-0.8': 'epfl-dlab/SynthIE/1rgxe7t7'}

# %%
run_name2wandb_path = {
 'inf_fe_fully_synthetic_gcp_large_last_datamodule-sdg_text_davinci_003_world-genie_t5_tokenizeable_split-test_small_ordered_constraint-R-max-T5_lp-0.8': 'epfl-dlab/SynthIE/1rgxe7t7',
 'inf_fe_fully_synthetic_gcp_large_last_datamodule-sdg_code_davinci_002_world-genie_t5_tokenizeable_split-test_small_ordered_constraint-R-max-T5_lp-0.8': 'epfl-dlab/SynthIE/w2qbchl7',
 'inf_fe_fully_synthetic_gcp_large_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.6': 'epfl-dlab/SynthIE/1l771cuv',
 'inf_fe_fully_synthetic_gcp_large_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.8': 'epfl-dlab/SynthIE/26x7v8sl',
 'inf_fe_fully_synthetic_gcp_large_last_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-free_lp-0.6': 'epfl-dlab/SynthIE/27o5dwor',
 'inf_fe_fully_synthetic_gcp_large_last_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-free_lp-0.8': 'epfl-dlab/SynthIE/3qcgni65'
 }


# Useful for the process_results launcher
print(" ".join(list(run_name2wandb_path.values())))
# Out:
# epfl-dlab/SynthIE/1rgxe7t7 epfl-dlab/SynthIE/w2qbchl7 epfl-dlab/SynthIE/1l771cuv epfl-dlab/SynthIE/26x7v8sl epfl-dlab/SynthIE/27o5dwor epfl-dlab/SynthIE/3qcgni65

# %%
# ~~~ Which experiments to consider? ~~~
# model_id_wandb_run_path_pairs = [("R", "martinj96/SynthIE/izr0vgpw"), ("R+S", "martinj96/SynthIE/2f857wrl"), ("R", "martinj96/SynthIE/3274th6j"), ("R+S", "martinj96/SynthIE/runs/22djwbxk")]
model_id_wandb_run_path_pairs = [("Code-Best", wandb_path) if "_last_" in run_name else ("Rebel-Best", wandb_path) for run_name, wandb_path in run_name2wandb_path.items()][::-1]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# ~~~ What to report? ~~~~
PRESENT_QUANTITATIVE_RESULTS = True
PRESENT_MACRO_RESULTS = True

PRESENT_QUALITATIVE_RESULTS = True
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# ~~~ Qauntitative results ~~~
metrics = ["triplet_set_precision", "triplet_set_recall", "triplet_set_f1"]

n_bootstrap_samples = 10  # Set to None to present only the corpus level metric (without confidence intervals)
confidence_level = 0.95
confidence_interval_type = "std"
assert confidence_interval_type in ["percentile", "std"]

metric_name2label = {"triplet_set_precision": "P", "triplet_set_recall": "R", "triplet_set_f1": "F1"}
dataset_name2dataset_label = {"rebel": "REBEL", "sdg_code_davinci_002": "[SDG] Code Davinci", "sdg_text_davinci_003": "[SGD] Text Davinci"}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# ~~~ Qualitative results ~~~
n_samples = 20
n_predictions_to_show = 1
barplot_capsize = 0

# Note that if you change the below flags, the presented predictions will correspond to a processed version of the actual (exact) output
present_triplets_in_the_canonical_linearization = False # the canonical linearization is fully_expanded
keep_duplicate_triplets = True
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ##### Define Experiment ID

# %%
# ~~~ Optional ~~~~
def retrieve_constraint_module_id(hydra_config):
    cm_cfg = hydra_config['model']['constraint_module']

    if cm_cfg == None or cm_cfg == 'None':
        return "free"

    identifier2label = {'genie': 'R-max'}
    return identifier2label.get(cm_cfg['identifier'], cm_cfg['identifier'])

def retrieve_lenght_penalty(hydra_config):
    return hydra_config['model']['hparams_overrides']['inference']['hf_generation_params']['length_penalty']
# ~~~~~~~~~~~~~~~~~~

# The names of these functions should not change    
def get_exp_id(model_id, hydra_config):
    return f"{model_id} -- ({retrieve_constraint_module_id(hydra_config)}) lp_{retrieve_lenght_penalty(hydra_config)} [{dataset_name2dataset_label[retrieve_dataset_name(hydra_config)]}]"

def retrieve_dataset_name(hydra_config):
    return hydra_config['datamodule']['name']

results_df_field2getter = {"LP": retrieve_lenght_penalty, "Constraint": retrieve_constraint_module_id}
barplot_hue_ordering = ['Model', 'LP', 'Constraint']
results_ordering = barplot_hue_ordering

# %% [markdown]
# ## Main Part

# %%
wandb_configs = {}
hydra_configs = {}
abs_exp_dirs = {}

output_datasets = {}
results = {}

exp_id2wandb_run_path = {}
exp_id2model_id = {}

for model_id, wandb_run_path in model_id_wandb_run_path_pairs:
    api = wandb.Api()
    run = api.run(wandb_run_path)
    wandb_config, hydra_config, abs_exp_dir = evaluation_helpers.prepare_data_for_experiment(wandb_run_path, work_dir, print)
    exp_id = get_exp_id(model_id, hydra_config)
    exp_id2wandb_run_path[exp_id] = wandb_run_path
    exp_id2model_id[exp_id] = model_id

    wandb_configs[exp_id], hydra_configs[exp_id], abs_exp_dirs[exp_id] = wandb_config, hydra_config, abs_exp_dir

    # Load predictions data
    linearization_class_id = hydra_configs[exp_id]['datamodule'].get("linearization_class_id", None)
    if linearization_class_id is None:
        # Left for backward compatibility
        print("Linearization class ID not specified. Using the default one `fully_expanded_et`")
        linearization_class_id = "fully_expanded_et"
    data_dir = os.path.join(abs_exp_dirs[exp_id], "predictions")
    output_datasets[exp_id] = IEGenericOutputDataset(data_dir=data_dir, seed=123, linearization_class_id=linearization_class_id)

    # Load existing results data
    results[exp_id] = evaluation_helpers.Results(abs_exp_dirs[exp_id])

exp_ids = list(results.keys())
# Out:
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_fe_fully_synthetic_gcp_large_last_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-free_lp-0.8/2023-01-29_22-34-33
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_fe_fully_synthetic_gcp_large_last_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-free_lp-0.6/2023-01-29_22-52-40
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_fe_fully_synthetic_gcp_large_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.8/2023-01-29_21-44-02
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_fe_fully_synthetic_gcp_large_datamodule-rebel_world-genie_t5_tokenizeable_split-test_small_constraint-R-max-T5_lp-0.6/2023-01-29_23-57-58
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_fe_fully_synthetic_gcp_large_last_datamodule-sdg_code_davinci_002_world-genie_t5_tokenizeable_split-test_small_ordered_constraint-R-max-T5_lp-0.8/2023-01-30_12-51-34
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_fe_fully_synthetic_gcp_large_last_datamodule-sdg_text_davinci_003_world-genie_t5_tokenizeable_split-test_small_ordered_constraint-R-max-T5_lp-0.8/2023-01-30_12-35-27
# Loading the existing results

# %%
def display_results(metrics, metric_labels):
    # Retrieve information
    results_dfs = []
    for exp_id in exp_id2wandb_run_path.keys():
        curr_results = results[exp_id]
        
        if n_bootstrap_samples is None:
            y = [curr_results.get_score(metric_id, per_bucket=False) for metric_id in metrics]
            yerr = None
        else:
            y = []
            yerr = []
            for metric_id in metrics:
                # print(metric_id)
                if confidence_interval_type == "percentile":
                    lower, mean, upper = curr_results.get_percentile_based_ci(metric_id, 
                                                                              confidence_level=confidence_level,
                                                                              n_bootstrap_samples=n_bootstrap_samples,
                                                                              dataset_id=None)
                    y.append(mean)
                    yerr.append((mean-lower, upper-mean))
                elif confidence_interval_type == "std":
                    lower, mean, upper = curr_results.get_std_based_ci(metric_id, 
                                                                       n_bootstrap_samples=n_bootstrap_samples, 
                                                                       dataset_id=None)
                    y.append(mean)
                    yerr.append((mean-lower, upper-mean))
                else:
                    raise ValueError(f"Unknown confidence interval type: {confidence_interval_type}")

            yerr = np.array(yerr).T

        # create a datataframe
        if yerr is not None:
            df = pd.DataFrame({'Metric': metric_labels, 'Score': y, 'ci_score_lower': yerr[0, :], 'ci_score_upper': yerr[1, :]})
        else:
            df = pd.DataFrame({'Metric': metric_labels, 'Score': y})
        
        # required fields
        df['Exp_ID'] = [exp_id] * df.shape[0]
        df['Dataset'] = [retrieve_dataset_name(hydra_configs[exp_id])] * df.shape[0]
        df['Model'] = [exp_id2model_id[exp_id]] * df.shape[0]

        # optional fields
        if results_df_field2getter is not None:
            for field_name, getter in results_df_field2getter.items():
                df[field_name] = [getter(hydra_configs[exp_id])] * df.shape[0]
        results_dfs.append(df)

    results_df = pd.concat(results_dfs, axis=0)
    
    # Massage the data
    dataset_names = results_df['Dataset'].unique()

    per_dataset_results_long = {}
    per_dataset_results_wide = {}

    per_dataset_results_ci_lower = {}
    per_dataset_results_ci_upper = {}

    for dataset_name in dataset_names:
        dataset_long_df = results_df[results_df['Dataset'] == dataset_name].copy()
        # set the error term to the average of the empirical lower and upper confidence interval delta
        # dataset_long_df['Error'] = ((dataset_long_df['ci_score_lower'] + dataset_long_df['ci_score_upper']) / 2)
        # dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + ' ± ' + (dataset_long_df['Error']*100).round(2).astype(str)
        if n_bootstrap_samples is not None:
            dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + " [" + ((dataset_long_df['Score']-dataset_long_df['ci_score_lower'])*100).round(2).astype(str) + ", " + ((dataset_long_df['Score'] + dataset_long_df['ci_score_upper'])*100).round(2).astype(str) + "]"
            scores_column = 'Score_with_ci'
        else:
            dataset_long_df['Score_without_ci'] =  (dataset_long_df['Score']*100).round(2).astype(str)
            scores_column = 'Score_without_ci'
        
        per_dataset_results_long[dataset_name] = dataset_long_df

        pivot_index = ['Model']
        if results_df_field2getter is not None:
            pivot_index.extend(list(results_df_field2getter.keys()))
        dataset_wide_df = dataset_long_df.pivot_table(index=pivot_index, columns='Metric', values=scores_column, aggfunc=lambda x: ' '.join(x))
        dataset_wide_df = dataset_wide_df[['P', 'R', 'F1']]
        per_dataset_results_wide[dataset_name] = dataset_wide_df

    results_wide_df = pd.concat(per_dataset_results_wide.values(), keys=per_dataset_results_wide.keys(), names=['Dataset'], axis=1)
    results_wide_df = results_wide_df.sort_index(axis=0, level=results_ordering)
    results_wide_df.columns = pd.MultiIndex.from_tuples([(dataset_name2dataset_label[dataset_name], metric) for dataset_name, metric in results_wide_df.columns.values], names=['Dataset', f'Metric [{int(confidence_level*100)}% CI]'])
    
    display(results_wide_df)

if PRESENT_QUANTITATIVE_RESULTS:
    print("~~~ Micro ~~~")
    metric_labels = [metric_name2label[metric_id] for metric_id in metrics]
    display_results(metrics, metric_labels)

    print("~~~ Macro ~~~~")
    if PRESENT_MACRO_RESULTS:
        macro_metrics = [f"macro_{metric}" for metric in metrics]
        display_results(macro_metrics, metric_labels)
# Out:
# ~~~ Micro ~~~
# Dataset                                              REBEL  \
# Metric [95% CI]                                          P
# Model      LP  Constraint
# Code-Best  0.6 free                   18.83 [17.01, 20.64]
#            0.8 free                   17.29 [15.76, 18.82]
#                genie_t5_tokenizeable                   NaN
# Rebel-Best 0.6 genie_t5_tokenizeable  20.07 [18.39, 21.74]
#            0.8 genie_t5_tokenizeable   17.78 [17.3, 18.26]
#
# Dataset                                                     \
# Metric [95% CI]                                          R
# Model      LP  Constraint
# Code-Best  0.6 free                    18.3 [16.94, 19.66]
#            0.8 free                   20.75 [19.42, 22.08]
#                genie_t5_tokenizeable                   NaN
# Rebel-Best 0.6 genie_t5_tokenizeable   23.42 [22.3, 24.54]
#            0.8 genie_t5_tokenizeable   26.53 [26.0, 27.05]
#
# Dataset                                                     \
# Metric [95% CI]                                         F1
# Model      LP  Constraint
# Code-Best  0.6 free                   18.56 [17.01, 20.11]
#            0.8 free                   18.86 [17.45, 20.26]
#                genie_t5_tokenizeable                   NaN
# Rebel-Best 0.6 genie_t5_tokenizeable  21.61 [20.25, 22.97]
#            0.8 genie_t5_tokenizeable  21.29 [20.81, 21.78]
#
# Dataset                                 [SDG] Code Davinci  \
# Metric [95% CI]                                          P
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  83.46 [82.26, 84.65]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
#
# Dataset                                                     \
# Metric [95% CI]                                          R
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  74.48 [73.44, 75.52]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
#
# Dataset                                                     \
# Metric [95% CI]                                         F1
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  78.71 [77.81, 79.61]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
#
# Dataset                                 [SGD] Text Davinci  \
# Metric [95% CI]                                          P
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  93.66 [93.09, 94.24]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
#
# Dataset                                                    \
# Metric [95% CI]                                         R
# Model      LP  Constraint
# Code-Best  0.6 free                                   NaN
#            0.8 free                                   NaN
#                genie_t5_tokenizeable  92.61 [91.82, 93.4]
# Rebel-Best 0.6 genie_t5_tokenizeable                  NaN
#            0.8 genie_t5_tokenizeable                  NaN
#
# Dataset
# Metric [95% CI]                                         F1
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  93.14 [92.48, 93.79]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
# ~~~ Macro ~~~~
# Dataset                                            REBEL  \
# Metric [95% CI]                                        P
# Model      LP  Constraint
# Code-Best  0.6 free                    7.48 [6.71, 8.26]
#            0.8 free                     6.87 [5.94, 7.8]
#                genie_t5_tokenizeable                 NaN
# Rebel-Best 0.6 genie_t5_tokenizeable  9.47 [8.75, 10.18]
#            0.8 genie_t5_tokenizeable   8.07 [7.66, 8.47]
#
# Dataset                                                                        \
# Metric [95% CI]                                          R                 F1
# Model      LP  Constraint
# Code-Best  0.6 free                    10.28 [9.64, 10.92]  7.61 [6.83, 8.38]
#            0.8 free                     10.51 [9.5, 11.51]   7.36 [6.4, 8.32]
#                genie_t5_tokenizeable                   NaN                NaN
# Rebel-Best 0.6 genie_t5_tokenizeable  11.15 [10.16, 12.14]   8.84 [8.3, 9.37]
#            0.8 genie_t5_tokenizeable  13.18 [12.54, 13.82]  8.63 [8.22, 9.04]
#
# Dataset                                [SDG] Code Davinci  \
# Metric [95% CI]                                         P
# Model      LP  Constraint
# Code-Best  0.6 free                                   NaN
#            0.8 free                                   NaN
#                genie_t5_tokenizeable  82.48 [79.6, 85.37]
# Rebel-Best 0.6 genie_t5_tokenizeable                  NaN
#            0.8 genie_t5_tokenizeable                  NaN
#
# Dataset                                                     \
# Metric [95% CI]                                          R
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  77.15 [75.84, 78.45]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
#
# Dataset                                                     \
# Metric [95% CI]                                         F1
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  78.09 [76.75, 79.44]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
#
# Dataset                                 [SGD] Text Davinci  \
# Metric [95% CI]                                          P
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  93.86 [93.51, 94.21]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN
#
# Dataset                                                    \
# Metric [95% CI]                                         R
# Model      LP  Constraint
# Code-Best  0.6 free                                   NaN
#            0.8 free                                   NaN
#                genie_t5_tokenizeable  93.72 [93.03, 94.4]
# Rebel-Best 0.6 genie_t5_tokenizeable                  NaN
#            0.8 genie_t5_tokenizeable                  NaN
#
# Dataset
# Metric [95% CI]                                         F1
# Model      LP  Constraint
# Code-Best  0.6 free                                    NaN
#            0.8 free                                    NaN
#                genie_t5_tokenizeable  93.38 [93.03, 93.73]
# Rebel-Best 0.6 genie_t5_tokenizeable                   NaN
#            0.8 genie_t5_tokenizeable                   NaN

# %%
def display_barplots(metrics, metric_labels):
    # Retrieve information
    results_dfs = []
    for exp_id in exp_id2wandb_run_path.keys():
        curr_results = results[exp_id]
        
        if n_bootstrap_samples is None:
            y = [curr_results.get_score(metric_id, per_bucket=False) for metric_id in metrics]
            yerr = None
        else:
            y = []
            yerr = []
            for metric_id in metrics:
                # print(metric_id)
                if confidence_interval_type == "percentile":
                    lower, mean, upper = curr_results.get_percentile_based_ci(metric_id, 
                                                                              confidence_level=confidence_level,
                                                                              n_bootstrap_samples=n_bootstrap_samples,
                                                                              dataset_id=None)
                elif confidence_interval_type == "std":
                    lower, mean, upper = curr_results.get_std_based_ci(metric_id, 
                                                                       n_bootstrap_samples=n_bootstrap_samples, 
                                                                       dataset_id=None)
                else:
                    raise ValueError(f"Unknown confidence interval type: {confidence_interval_type}")
                y.append(mean)
                yerr.append((mean-lower, upper-mean))

            yerr = np.array(yerr).T

        # create a datataframe
        if yerr is not None:
            df = pd.DataFrame({'Metric': metric_labels, 'Score': y, 'ci_score_lower': yerr[0, :], 'ci_score_upper': yerr[1, :]})
        else:
            df = pd.DataFrame({'Metric': metric_labels, 'Score': y})
        
        # required fields
        df['Exp_ID'] = [exp_id] * df.shape[0]
        df['Dataset'] = [retrieve_dataset_name(hydra_configs[exp_id])] * df.shape[0]
        df['Model'] = [exp_id2model_id[exp_id]] * df.shape[0]

        # optional fields
        if results_df_field2getter is not None:
            for field_name, getter in results_df_field2getter.items():
                df[field_name] = [getter(hydra_configs[exp_id])] * df.shape[0]
        results_dfs.append(df)

    results_df = pd.concat(results_dfs, axis=0)
    
    # Massage the data
    dataset_names = results_df['Dataset'].unique()

    per_dataset_results_long = {}
    per_dataset_results_wide = {}

    per_dataset_results_ci_lower = {}
    per_dataset_results_ci_upper = {}

    for dataset_name in dataset_names:
        dataset_long_df = results_df[results_df['Dataset'] == dataset_name].copy()
        # set the error term to the average of the empirical lower and upper confidence interval delta
        # dataset_long_df['Error'] = ((dataset_long_df['ci_score_lower'] + dataset_long_df['ci_score_upper']) / 2)
        # dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + ' ± ' + (dataset_long_df['Error']*100).round(2).astype(str)
        if n_bootstrap_samples is not None:
            dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + " [" + ((dataset_long_df['Score']-dataset_long_df['ci_score_lower'])*100).round(2).astype(str) + ", " + ((dataset_long_df['Score'] + dataset_long_df['ci_score_upper'])*100).round(2).astype(str) + "]"
            scores_column = 'Score_with_ci'
        else:
            dataset_long_df['Score_without_ci'] =  (dataset_long_df['Score']*100).round(2).astype(str)
            scores_column = 'Score_without_ci'
        
        per_dataset_results_long[dataset_name] = dataset_long_df

        pivot_index = ['Model']
        if results_df_field2getter is not None:
            pivot_index.extend(list(results_df_field2getter.keys()))
        dataset_wide_df = dataset_long_df.pivot_table(index=pivot_index, columns='Metric', values=scores_column, aggfunc=lambda x: ' '.join(x))
        dataset_wide_df = dataset_wide_df[['P', 'R', 'F1']]
        per_dataset_results_wide[dataset_name] = dataset_wide_df

    results_wide_df = pd.concat(per_dataset_results_wide.values(), keys=per_dataset_results_wide.keys(), names=['Dataset'], axis=1)
    results_wide_df = results_wide_df.sort_index(axis=0, level=results_ordering)
    results_wide_df.columns = pd.MultiIndex.from_tuples([(dataset_name2dataset_label[dataset_name], metric) for dataset_name, metric in results_wide_df.columns.values], names=['Dataset', f'Metric [{int(confidence_level*100)}% CI]'])

    # get a subplot for each dataset
    figsize = (10, 7 * len(dataset_names))
    fig, axes = plt.subplots(len(dataset_names), 1, figsize=figsize, sharex=True, sharey=True)
    
    if len(dataset_names) == 1:
        axes = [axes]

    for ax, dataset_name in zip(axes, dataset_names):
        dataset_results_long_df = per_dataset_results_long[dataset_name]
        # sort the dataframe accoring to the Constraint, Model and LP
        if barplot_hue_ordering is not None:
            dataset_results_long_df = dataset_results_long_df.sort_values(by=barplot_hue_ordering)
        dataset_results_long_df.reset_index(inplace=True, drop=True)

        hue_order = dataset_results_long_df['Exp_ID'].drop_duplicates().values.tolist()
        order = ['P', 'R', 'F1']
        sns.barplot(ax=ax, data=dataset_results_long_df, x='Metric', y="Score", hue='Exp_ID', edgecolor="black", palette='deep', order=order, hue_order=hue_order)

        ax.set_title(dataset_name2dataset_label[dataset_name])
        ax.set_ylabel("Score")
        ax.set_ylim(0,1)
        if ax != axes[0]:
            ax.set_xlabel("Metric")
        else:
            ax.set_xlabel("")

        # remove the box around the legend
        ax.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1, frameon=False)

        if 'ci_score_lower' in dataset_results_long_df.columns:
            x_coords = [p.get_x() + 0.5 * p.get_width() for p in ax.patches]
            y_coords = [p.get_height() for p in ax.patches]

            dataset_results_long_df.Exp_ID = pd.Categorical(dataset_results_long_df.Exp_ID, categories=hue_order, ordered=True)
            dataset_results_long_df.Metric = pd.Categorical(dataset_results_long_df.Metric, categories=order, ordered=True)
            error = np.stack([dataset_results_long_df.sort_values(by=['Exp_ID', 'Metric'])['ci_score_lower'].values, dataset_results_long_df.sort_values(by=['Exp_ID', 'Metric'])['ci_score_upper'].values])
            ax.errorbar(x=x_coords, y=y_coords, yerr=error, fmt="none", color="black", capsize=barplot_capsize, zorder=10000)
    
    plt.show()

# Figure for the table above
if PRESENT_QUANTITATIVE_RESULTS:
    print("~~~ Micro ~~~")
    metric_labels = [metric_name2label[metric_id] for metric_id in metrics]
    display_barplots(metrics, metric_labels)

    print("~~~ Macro ~~~~")
    if PRESENT_MACRO_RESULTS:
        macro_metrics = [f"macro_{metric}" for metric in metrics]
        display_barplots(macro_metrics, metric_labels)
# Out:
# ~~~ Micro ~~~
# ~~~ Macro ~~~~

# %%
def get_predictions_df(exp_ids):
    global n_predictions_to_show
    random_ids = None

    pred_dfs = []

    for exp_id in exp_ids:
        output_dataset = output_datasets[exp_id]

        
        if random_ids is None:
            random_indices = np.random.RandomState(seed).choice(len(output_dataset),  min([n_samples, len(output_dataset)]), replace=False)
            random_ids = set([output_dataset.data[i]['id'] for i in random_indices])

        random_sample = [output_dataset.data[i] for i in random_indices if output_dataset.data[i]['id'] in random_ids]

        if present_triplets_in_the_canonical_linearization or not keep_duplicate_triplets:
            if n_predictions_to_show != 1:
                n_predictions_to_show = 1
                print(f"present_triplets_in_the_canonical_linearization={present_triplets_in_the_canonical_linearization} or keep_duplicate_triplets={keep_duplicate_triplets} supported only when n_predictions_to_show=1. Setting n_predictions_to_show=1")

        ids = [sample['id'] for sample in random_sample]
        inputs = [sample['input'] for sample in random_sample]
        targets = [sample['target'] for sample in random_sample]
        predictions = [sample['prediction'][0] if n_predictions_to_show == 1 else sample['prediction'][:n_predictions_to_show] for sample in random_sample]
        
        if present_triplets_in_the_canonical_linearization or not keep_duplicate_triplets:
            targets_triplets = [output_dataset.get_text_triples(target, return_set=(not keep_duplicate_triplets)) for target in targets]
            predictions_triplets = [output_dataset.get_text_triples(prediction, return_set=(not keep_duplicate_triplets)) for prediction in predictions]
            print("gaga")
            if present_triplets_in_the_canonical_linearization:
                lc = utils.get_linearization_class("fully_expanded")
            else:
                lc = output_dataset.linearization_class
            
            targets = [lc.triplet_list_to_text(triplets)[0] for triplets in targets_triplets]
            predictions = [lc.triplet_list_to_text(triplets)[0] for triplets in predictions_triplets]

        df = pd.DataFrame(list(zip(ids, inputs, targets, predictions)), columns=['id', 'input', 'target', f'prediction_{exp_id}'])
        pred_dfs.append(df)

    predictions_df = reduce(lambda  left,right: pd.merge(left,right,on=['id', 'input', 'target'], how='inner', ), pred_dfs)
    predictions_df.sort_values(by=['id'], inplace=True)
    assert(predictions_df.shape[0] == len(random_ids))
    return predictions_df


def wrap_df_text(df, input_max_col):
    tdf = df.copy()
    tdf['input'] = tdf['input'].str.wrap(input_max_col)
    tdf['target'] = tdf['target'].str.replace("\[e\]|\[et\]", "[e]\\n", regex=True)

    for col in tdf.columns:
        if col.startswith("prediction"):
            if type(tdf[col][0]) == str:
                tdf[col] = tdf[col].str.replace("\[e\]|\[et\]", "[e]\\n", regex=True)
            else:
                tdf[col] = tdf[col].apply(lambda x: "\\n".join([re.sub("\[e\]|\[et\]", "[e]\\n", p) for p in x]))

    display(HTML(tdf.to_html().replace("\\n","<br>")))


if PRESENT_QUALITATIVE_RESULTS:
    seed = 123

    # get the dataset_name for each experiment
    dataset_names = list([retrieve_dataset_name(hydra_configs[exp_id]) for exp_id in exp_ids])

    for dataset_name in set(dataset_names):
        print(f"~~~~ {dataset_name2dataset_label[dataset_name]} ~~~~")
        exp_ids_to_visualize = [exp_id for exp_id, exp_dataset_name in zip(exp_ids, dataset_names) if exp_dataset_name  == dataset_name]
        print(exp_ids_to_visualize)
        predictions_df = get_predictions_df(exp_ids_to_visualize)

        with pd.option_context('display.max_rows', None, 'display.max_columns', None, "display.expand_frame_repr", False, 'display.max_colwidth', None, 'display.width', None):        
            wrap_df_text(predictions_df, 50)
# Out:
# ~~~~ REBEL ~~~~
# ['Code-Best -- (free) lp_0.8 [REBEL]', 'Code-Best -- (free) lp_0.6 [REBEL]', 'Rebel-Best -- (genie_t5_tokenizeable) lp_0.8 [REBEL]', 'Rebel-Best -- (genie_t5_tokenizeable) lp_0.6 [REBEL]']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>input</th>
#       <th>target</th>
#       <th>prediction_Code-Best -- (free) lp_0.8 [REBEL]</th>
#       <th>prediction_Code-Best -- (free) lp_0.6 [REBEL]</th>
#       <th>prediction_Rebel-Best -- (genie_t5_tokenizeable) lp_0.8 [REBEL]</th>
#       <th>prediction_Rebel-Best -- (genie_t5_tokenizeable) lp_0.6 [REBEL]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15</th>
#       <td>2033</td>
#       <td>Bastian Kersaudy (born 9 June 1994) is a French<br>badminton player from the Chambly Oise club.</td>
#       <td>[s] Bastian_Kersaudy [r] sport [o] Badminton [e]<br></td>
#       <td>[s] Bastian_Kersaudy [r] languages spoken, written or signed [o] French_language [e]<br> [s] Bastian_Kersaudy [r] member of sports team [o] Chambly_Oise [e]<br> [s] Bastian_Kersaudy [r] country for sport [o] France [e]<br></td>
#       <td>[s] Bastian_Kersaudy [r] languages spoken, written or signed [o] French_language [e]<br> [s] Bastian_Kersaudy [r] member of sports team [o] Chambly_Oise [e]<br></td>
#       <td>[s] Bastian_Kersaudy [r] languages spoken, written or signed [o] French_language [e]<br> [s] Bastian_Kersaudy [r] sport [o] Badminton [e]<br> [s] Bastian_Kersaudy [r] country for sport [o] France [e]<br> [s] France [r] coextensive with [o] France_(European_Parliament_constituency) [e]<br></td>
#       <td>[s] Bastian_Kersaudy [r] languages spoken, written or signed [o] French_language [e]<br> [s] Bastian_Kersaudy [r] sport [o] Badminton [e]<br> [s] Bastian_Kersaudy [r] country for sport [o] France [e]<br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3736</td>
#       <td>Peasley Cross railway station served the central<br>southern area of St Helens, England.</td>
#       <td>[s] Peasley_Cross_railway_station [r] instance of [o] Train_station [e]<br></td>
#       <td>[s] Peasley_Cross_railway_station [r] country [o] United_Kingdom [e]<br></td>
#       <td>[s] Peasley_Cross_railway_station [r] country [o] United_Kingdom [e]<br></td>
#       <td>[s] Peasley_Cross_railway_station [r] country [o] United_Kingdom [e]<br></td>
#       <td>[s] Peasley_Cross_railway_station [r] country [o] United_Kingdom [e]<br></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>6235</td>
#       <td>New Joc City is the debut album by American rapper<br>Yung Joc.</td>
#       <td>[s] New_Joc_City [r] performer [o] Yung_Joc [e]<br></td>
#       <td>[s] New_Joc_City [r] instance of [o] Album [e]<br> [s] New_Joc_City [r] performer [o] Yung_Joc [e]<br></td>
#       <td>[s] New_Joc_City [r] instance of [o] Album [e]<br> [s] New_Joc_City [r] performer [o] Yung_Joc [e]<br></td>
#       <td>[s] New_Joc_City [r] instance of [o] Album [e]<br> [s] New_Joc_City [r] performer [o] Yung_Joc [e]<br></td>
#       <td>[s] New_Joc_City [r] instance of [o] Album [e]<br> [s] New_Joc_City [r] performer [o] Yung_Joc [e]<br></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>6302</td>
#       <td>For this film Manfredi was awarded with a David di<br>Donatello for Best Actor.</td>
#       <td>[s] David_di_Donatello [r] has part [o] David_di_Donatello_for_Best_Actor [e]<br> [s] David_di_Donatello_for_Best_Actor [r] instance of [o] David_di_Donatello [e]<br></td>
#       <td>[s] Manfredi_(film) [r] award received [o] David_di_Donatello_for_Best_Actor [e]<br></td>
#       <td>[s] Manfredi_(film) [r] award received [o] David_di_Donatello_for_Best_Actor [e]<br></td>
#       <td>[s] Giuseppe_Manfredi [r] award received [o] David_di_Donatello_for_Best_Actor [e]<br></td>
#       <td>[s] Giuseppe_Manfredi [r] award received [o] David_di_Donatello_for_Best_Actor [e]<br></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>6496</td>
#       <td>Vred is a commune in the Nord department in<br>northern France.</td>
#       <td>[s] Vred [r] instance of [o] Communes_of_France [e]<br> [s] Vred [r] located in the administrative territorial entity [o] Nord_(French_department) [e]<br> [s] Nord_(French_department) [r] instance of [o] Departments_of_France [e]<br> [s] Nord_(French_department) [r] country [o] France [e]<br></td>
#       <td>[s] Vred [r] located in the administrative territorial entity [o] Nord_(French_department) [e]<br></td>
#       <td>[s] Vred [r] located in the administrative territorial entity [o] Nord_(French_department) [e]<br></td>
#       <td>[s] Vred [r] located in the administrative territorial entity [o] Nord_(French_department) [e]<br></td>
#       <td>[s] Vred [r] located in the administrative territorial entity [o] Nord_(French_department) [e]<br></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>8559</td>
#       <td>Homosassa platella is a species of snout moth in<br>the genus "Homosassa".</td>
#       <td>[s] Homosassa_platella [r] parent taxon [o] Homosassa_(moth) [e]<br> [s] Homosassa_(moth) [r] parent taxon [o] Pyralidae [e]<br></td>
#       <td>[s] Homosassa_platella [r] parent taxon [o] Homosassa [e]<br> [s] Homosassa_platella [r] taxon rank [o] Species [e]<br></td>
#       <td>[s] Homosassa_platella [r] parent taxon [o] Homosassa [e]<br> [s] Homosassa_platella [r] taxon rank [o] Species [e]<br></td>
#       <td>[s] Homosassa_platella [r] parent taxon [o] Homosassa_(moth) [e]<br> [s] Homosassa_platella [r] taxon rank [o] Species [e]<br> [s] Homosassa_platella [r] instance of [o] Taxon [e]<br></td>
#       <td>[s] Homosassa_platella [r] parent taxon [o] Homosassa_(moth) [e]<br> [s] Homosassa_platella [r] taxon rank [o] Species [e]<br> [s] Homosassa_platella [r] instance of [o] Taxon [e]<br></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>11106</td>
#       <td>Triple J's One Night Stand is a concert hosted in<br>a remote town or city in Australia annually.</td>
#       <td>[s] Triple_J's_One_Night_Stand [r] country [o] Australia [e]<br></td>
#       <td>[s] Triple_J's_One_Night_Stand [r] broadcast by [o] Triple_J [e]<br> [s] Triple_J's_One_Night_Stand [r] country [o] Australia [e]<br></td>
#       <td>[s] Triple_J's_One_Night_Stand [r] broadcast by [o] Triple_J [e]<br> [s] Triple_J's_One_Night_Stand [r] country [o] Australia [e]<br></td>
#       <td>[s] Triple_J's_One_Night_Stand [r] broadcast by [o] Triple_J [e]<br> [s] Triple_J's_One_Night_Stand [r] country [o] Australia [e]<br></td>
#       <td>[s] Triple_J's_One_Night_Stand [r] broadcast by [o] Triple_J [e]<br> [s] Triple_J's_One_Night_Stand [r] country [o] Australia [e]<br></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>13602</td>
#       <td>The 1905 New Orleans Pelicans season represented<br>the New Orleans Pelicans baseball team in the<br>Southern Association and won their first league<br>pennant, finishing with a record of 84 – 45.</td>
#       <td>[s] New_Orleans_Pelicans_(baseball) [r] league [o] Southern_Association [e]<br></td>
#       <td>[s] 1905_New_Orleans_Pelicans_season [r] season of club or team [o] New_Orleans_Pelicans [e]<br> [s] 1905_New_Orleans_Pelicans_season [r] sport [o] Baseball [e]<br> [s] 1905_New_Orleans_Pelicans_season [r] country [o] United_States [e]<br></td>
#       <td>[s] 1905_New_Orleans_Pelicans_season [r] season of club or team [o] New_Orleans_Pelicans [e]<br> [s] 1905_New_Orleans_Pelicans_season [r] sport [o] Baseball [e]<br></td>
#       <td>[s] 1905_New_York_Giants_season [r] season of club or team [o] New_York_Giants [e]<br> [s] 1905_New_York_Giants_season [r] sport [o] Baseball [e]<br> [s] 1905_New_York_Giants_season [r] country [o] United_States [e]<br> [s] Baseball [r] authority [o] World_Baseball_Softball_Confederation [e]<br> [s] Baseball [r] practiced by [o] Umpire_(baseball) [e]<br> [s] Baseball [r] practiced by [o] Manager_(baseball) [e]<br> [s] Baseball [r] practiced by [o] Umpire_(baseball) [e]<br> [s] Baseball [r] practiced by [o] Umpire_(baseball) [e]<br></td>
#       <td>[s] 1905_New_York_Giants_season [r] season of club or team [o] New_York_Giants [e]<br> [s] 1905_New_York_Giants_season [r] sport [o] Baseball [e]<br> [s] 1905_New_York_Giants_season [r] country [o] United_States [e]<br> [s] Baseball [r] authority [o] World_Baseball_Softball_Confed
# ~~~~ [SDG] Code Davinci ~~~~
# ['Code-Best -- (genie_t5_tokenizeable) lp_0.8 [[SDG] Code Davinci]']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>input</th>
#       <th>target</th>
#       <th>prediction_Code-Best -- (genie_t5_tokenizeable) lp_0.8 [[SDG] Code Davinci]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15</th>
#       <td>120</td>
#       <td>KWYY is a radio station in the United States,<br>owned by Townsquare Media.</td>
#       <td>[s] KWYY [r] country [o] United_States [e]<br> [s] KWYY [r] owned by [o] Townsquare_Media [e]<br></td>
#       <td>[s] KWYY [r] country [o] United_States [e]<br> [s] KWYY [r] owned by [o] Townsquare_Media [e]<br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>208</td>
#       <td>Rila Municipality is a municipality in Kyustendil<br>Province, Bulgaria, with the capital town Rila.</td>
#       <td>[s] Rila_Municipality [r] located in the administrative territorial entity [o] Kyustendil_Province [e]<br> [s] Rila_Municipality [r] capital [o] Rila,_Bulgaria [e]<br></td>
#       <td>[s] Rila_Municipality [r] capital [o] Rila [e]<br> [s] Rila_Municipality [r] located in the administrative territorial entity [o] Kyustendil_Province [e]<br> [s] Rila_Municipality [r] country [o] Bulgaria [e]<br></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>338</td>
#       <td>Supermarket Stakeout is a cooking competition show<br>hosted by chef Alex Guarnaschelli on the Food<br>Network.</td>
#       <td>[s] Supermarket_Stakeout [r] presenter [o] Alex_Guarnaschelli [e]<br> [s] Supermarket_Stakeout [r] original broadcaster [o] Food_Network [e]<br> [s] Alex_Guarnaschelli [r] occupation [o] Chef [e]<br></td>
#       <td>[s] Supermarket_Stakeout [r] presenter [o] Alex_Guarnaschelli [e]<br> [s] Supermarket_Stakeout [r] original broadcaster [o] Food_Network [e]<br></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>342</td>
#       <td>Fiction Weekly is a magazine, a type of periodical<br>literature, and a form of mass media. It is the<br>same as a journal.</td>
#       <td>[s] Fiction_Weekly [r] instance of [o] Magazine [e]<br> [s] Magazine [r] subclass of [o] Periodical_literature [e]<br> [s] Magazine [r] subclass of [o] Mass_media [e]<br> [s] Magazine [r] said to be the same as [o] Journal [e]<br> [s] Magazine [r] described by source [o] Armenian_Soviet_Encyclopedia [e]<br></td>
#       <td>[s] Fiction_Weekly [r] instance of [o] Magazine [e]<br> [s] Magazine [r] subclass of [o] Periodical_literature [e]<br> [s] Magazine [r] subclass of [o] Mass_media [e]<br> [s] Magazine [r] said to be the same as [o] Journal [e]<br></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>359</td>
#       <td>The 1982 Eastern Michigan Hurons football team<br>played their home games at Rynearson Stadium, in<br>Ypsilanti, Michigan.</td>
#       <td>[s] 1982_Eastern_Michigan_Hurons_football_team [r] season of club or team [o] Eastern_Michigan_Eagles [e]<br> [s] 1982_Eastern_Michigan_Hurons_football_team [r] home venue [o] Rynearson_Stadium [e]<br></td>
#       <td>[s] 1982_Eastern_Michigan_Hurons_football_team [r] season of club or team [o] Eastern_Michigan_Eagles [e]<br> [s] 1982_Eastern_Michigan_Hurons_football_team [r] home venue [o] Rynearson_Stadium [e]<br></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>476</td>
#       <td>Karin Hardt was a German sculptor who lived in the<br>20th century. She was married to Erich Waschneck.</td>
#       <td>[s] Karin_Hardt [r] time period [o] 20th_century [e]<br> [s] Karin_Hardt [r] spouse [o] Erich_Waschneck [e]<br></td>
#       <td>[s] Karin_Hardt [r] valid in period [o] 20th_century [e]<br> [s] Karin_Hardt [r] spouse [o] Erich_Waschneck [e]<br></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>607</td>
#       <td>The Pope of the Coptic Orthodox Church is the<br>leader of one of the Oriental Orthodox Churches.</td>
#       <td>[s] Pope_of_the_Coptic_Orthodox_Church [r] religion [o] Oriental_Orthodox_Churches [e]<br></td>
#       <td>[s] Pope_of_the_Coptic_Orthodox_Church [r] organization directed by the office or position [o] Oriental_Orthodox_Churches [e]<br></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>721</td>
#       <td>The Knole Settee is a couch that is on exhibition<br>at Knole, a National Trust property.</td>
#       <td>[s] Knole [r] maintained by [o] National_Trust [e]<br> [s] Knole_Settee [r] exhibition history [o] Knole [e]<br> [s] Knole_Settee [r] instance of [o] Couch [e]<br></td>
#       <td>[s] Knole [r] owned by [o] National_Trust [e]<br> [s] Knole_Settee [r] exhibition history [o] Knole [e]<br> [s] Knole_Settee [r] instance of [o] Couch [e]<br></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>859</td>
#       <td>The Unitarian League was an Argentine political<br>party.</td>
#       <td>[s] Unitarian_League [r] country [o] Argentina [e]<br></td>
#       <td>[s] Unitarian_League [r] instance of [o] Political_party [e]<br> [s] Unitarian_League [r] country [o] Argentina [e]<br></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1406</td>
#       <td>Vibration control is a facet of earthquake<br>engineering, which uses a tuned mass damper for<br>the mitigation of seismic motion.</td>
#       <td>[s] Vibration_control [r] facet of [o] Earthquake_engineering [e]<br> [s] Vibration_control [r] uses [o] Tuned_mass_damper [e]<br> [s] Vibration_control [r] permanent duplicated item [o] Mitigation_of_seismic_motion [e]<br> [s] Tuned_mass_damper [r] use [o] Earthquake_engineering [e]<br> [s] Mitigation_of_seismic_motion [r] permanent duplicated item [o] Vibration_control [e]<br></td>
#       <td>[s] Vibration_control [r] facet of [o] Earthquake_engineering [e]<br> [s] Vibration_control [r] uses [o] Tuned_mass_damper [e]<br> [s] Vibration_control [r] permanent duplicated item [o] Mitigation_of_seismic_motion [e]<br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1459</td>
#       <td>Regional cuisine is a cuisine that is associated<br>with a particular region or culture.</td>
#       <td>[s] Regional_cuisine [r] applies to part [o] Region [e]<br> [s] Regional_cuisine [r] subclass of [o] Cuisine [e]<br> [s] Regional_cuisine [r] part of [o] Culture [e]<br> [s] Regional_cuisine [r] applies to part [o] Social_group [e]<br></td>
#       <td>[s] Regional_cuisine [r] applies to part [o] Region [e]<br> [s] Regional_cuisine [r] subclass of [o] Cuisine [e]<br> [s] Regional_cuisine [r] part of [o] Culture [e]<br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1466</td>
#       <td>Kira Isabella's country music album Love Me Like<br>That was released in 2014.</td>
#       <td>[s] Kira_Isabella [r] educated at [o] St._Peter_Catholic_High_School [e]<br> [s] Love_Me_Like_That_(album) [r] performer [o] Kira_Isabella [e]<br> [s] Love_Me_Like_That_(album) [r] genre [o] Country_music [e]<br> [s] Love_Me_Like_That_(album) [r] instance of [o] Album [e]<br></td>
#       <td>[s] Love_Me_Like_That_(album) [r] performer [o] Kira_Isabella [e]<br> [s] Love_Me_Like_That_(album) [r] genre [o] Country_music [e]<br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1470</td>
#       <td>The 2013–14 Tunisian Ligue Professionnelle 1 was<br>the 71st season of top-tier football in Tunisia.<br>Espérance Sportive de Tunis were the defending<br>champions, having won their 13th title the<br>previous season. The season began on 28 August<br>2013 and ended on 31 May 2014. Espérance Sportive<br>de Tunis won their 14th title.</td>
#       <td>[s] 2013–14_Tunisian_Ligue_Professionnelle_1 [r] organizer [o] Tunisian_Football_Federation [e]<br> [s] 2013–14_Tunisian_Ligue_Professionnelle_1 [r] sports season of league or competition [o] Tunisian_Ligue_Professionnelle_1 [e]<br> [s] 2013–14_Tunisian_Ligue_Professionnelle_1 [r] sport [o] Association_football [e]<br> [s] 2013–14_Tunisian_Ligue_Professionnelle_1 [r] winner [o] Espérance_Sportive_de_Tunis [e]<br></td>
#       <td>[s] 2013–14_Tunisian_Ligue_Professionnelle_1 [r] sports season of league or competition [o] Tunisian_Ligue_Professionnelle_1 [e]<br> [s] 2013–14_Tunisian_Ligue_Professionnelle_1 [r] country [o] Tunisia [e]<br> [s] 2013–14_Tunisian_Ligue_Professionn
# ~~~~ [SGD] Text Davinci ~~~~
# ['Code-Best -- (genie_t5_tokenizeable) lp_0.8 [[SGD] Text Davinci]']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>input</th>
#       <th>target</th>
#       <th>prediction_Code-Best -- (genie_t5_tokenizeable) lp_0.8 [[SGD] Text Davinci]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15</th>
#       <td>117</td>
#       <td>GNOME Do depends on the Mono software.</td>
#       <td>[s] GNOME_Do [r] depends on software [o] Mono_(software) [e]<br></td>
#       <td>[s] GNOME_Do [r] depends on software [o] Mono_(software) [e]<br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>208</td>
#       <td>Nautilia nitratireducens is a species of Gram-<br>negative bacteria in the genus Nautilia, which is<br>a parent taxon and an instance of Taxon.</td>
#       <td>[s] Nautilia [r] Gram staining [o] Gram-negative_bacteria [e]<br> [s] Nautilia [r] taxon rank [o] Genus [e]<br> [s] Nautilia_nitratireducens [r] parent taxon [o] Nautilia [e]<br> [s] Nautilia_nitratireducens [r] taxon rank [o] Species [e]<br> [s] Nautilia_nitratireducens [r] instance of [o] Taxon [e]<br></td>
#       <td>[s] Nautilia_nitratireducens [r] parent taxon [o] Nautilia [e]<br> [s] Nautilia_nitratireducens [r] taxon rank [o] Species [e]<br> [s] Nautilia_nitratireducens [r] Gram staining [o] Gram-negative_bacteria [e]<br> [s] Nautilia_nitratireducens [r] instance of [o] Taxon [e]<br></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>334</td>
#       <td>Johan Gullichsen is a Finnish engineer and a<br>member of the Royal Swedish Academy of Engineering<br>Sciences. He is the son of Maire Gullichsen and<br>has two siblings, Lilli Alanen and Kristian<br>Gullichsen.</td>
#       <td>[s] Johan_Gullichsen [r] occupation [o] Engineer [e]<br> [s] Johan_Gullichsen [r] member of [o] Royal_Swedish_Academy_of_Engineering_Sciences [e]<br> [s] Johan_Gullichsen [r] mother [o] Maire_Gullichsen [e]<br> [s] Johan_Gullichsen [r] sibling [o] Lilli_Alanen [e]<br> [s] Johan_Gullichsen [r] sibling [o] Kristian_Gullichsen [e]<br> [s] Johan_Gullichsen [r] country of citizenship [o] Finland [e]<br></td>
#       <td>[s] Johan_Gullichsen [r] member of [o] Royal_Swedish_Academy_of_Engineering_Sciences [e]<br> [s] Johan_Gullichsen [r] father [o] Maire_Gullichsen [e]<br> [s] Johan_Gullichsen [r] sibling [o] Lilli_Alanen [e]<br> [s] Johan_Gullichsen [r] sibling [o] Kristian_Gullichsen [e]<br> [s] Johan_Gullichsen [r] country of citizenship [o] Finland [e]<br></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>338</td>
#       <td>Shocked quartz is a subclass of Quartz, which has<br>a black streak color and a quality of<br>piezoelectricity, differentiating it from<br>Cordierite.</td>
#       <td>[s] Shocked_quartz [r] subclass of [o] Quartz [e]<br> [s] Quartz [r] streak color [o] Black [e]<br> [s] Quartz [r] has quality [o] Piezoelectricity [e]<br> [s] Quartz [r] different from [o] Cordierite [e]<br></td>
#       <td>[s] Shocked_quartz [r] subclass of [o] Quartz [e]<br> [s] Quartz [r] streak color [o] Black [e]<br> [s] Quartz [r] has quality [o] Piezoelectricity [e]<br> [s] Quartz [r] different from [o] Cordierite [e]<br></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>355</td>
#       <td>Gray Hills is a landform located in the United<br>States.</td>
#       <td>[s] Gray_Hills [r] instance of [o] Landform [e]<br> [s] Gray_Hills [r] country [o] United_States [e]<br></td>
#       <td>[s] Gray_Hills [r] instance of [o] Landform [e]<br> [s] Gray_Hills [r] country [o] United_States [e]<br></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>470</td>
#       <td>Post-exertional malaise may present as fatigue and<br>fever in medical findings, and a blood test may be<br>conducted to examine fatigue.</td>
#       <td>[s] Post-exertional_malaise [r] possible medical findings [o] Fatigue [e]<br> [s] Post-exertional_malaise [r] possible medical findings [o] Fever [e]<br> [s] Fatigue [r] medical examinations [o] Blood_test [e]<br></td>
#       <td>[s] Post-exertional_malaise [r] possible medical findings [o] Fatigue [e]<br> [s] Post-exertional_malaise [r] possible medical findings [o] Fever [e]<br> [s] Fatigue [r] medical examinations [o] Blood_test [e]<br></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>597</td>
#       <td>John Henry Guinness was the father of Henry<br>Eustace Guinness and the spouse of Jennifer<br>Guinness. His given name was John.</td>
#       <td>[s] John_Henry_Guinness [r] given name [o] John_(given_name) [e]<br> [s] John_Henry_Guinness [r] father [o] Henry_Eustace_Guinness [e]<br> [s] John_Henry_Guinness [r] spouse [o] Jennifer_Guinness [e]<br></td>
#       <td>[s] John_Henry_Guinness [r] given name [o] John_(given_name) [e]<br> [s] John_Henry_Guinness [r] father [o] Henry_Eustace_Guinness [e]<br> [s] John_Henry_Guinness [r] spouse [o] Jennifer_Guinness [e]<br></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>707</td>
#       <td>Ponto Belo is a town in Brazil, sharing a border<br>with both Mucurici and Nova Venécia.</td>
#       <td>[s] Ponto_Belo [r] country [o] Brazil [e]<br> [s] Ponto_Belo [r] shares border with [o] Mucurici [e]<br> [s] Ponto_Belo [r] shares border with [o] Nova_Venécia [e]<br></td>
#       <td>[s] Ponto_Belo [r] country [o] Brazil [e]<br> [s] Ponto_Belo [r] shares border with [o] Mucurici [e]<br> [s] Ponto_Belo [r] shares border with [o] Nova_Venécia [e]<br></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>845</td>
#       <td>Charlotte Gower Chapman was born in Kankakee,<br>Illinois and was employed by both Lingnan<br>University and the Office of Strategic Services.<br>Her final resting place is the Pacific Ocean.</td>
#       <td>[s] Charlotte_Gower_Chapman [r] place of birth [o] Kankakee,_Illinois [e]<br> [s] Charlotte_Gower_Chapman [r] employer [o] Lingnan_University [e]<br> [s] Charlotte_Gower_Chapman [r] employer [o] Office_of_Strategic_Services [e]<br> [s] Charlotte_Gower_Chapman [r] place of burial [o] Pacific_Ocean [e]<br></td>
#       <td>[s] Charlotte_Gower_Chapman [r] place of birth [o] Kankakee,_Illinois [e]<br> [s] Charlotte_Gower_Chapman [r] employer [o] Lingnan_University [e]<br> [s] Charlotte_Gower_Chapman [r] employer [o] Office_of_Strategic_Services [e]<br> [s] Charlotte_Gower_Chapman [r] place of burial [o] Pacific_Ocean [e]<br></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1398</td>
#       <td>Earl Silverman is an instance of a Human, who is<br>modeled after Joan of Arc. Humans physically<br>interact with Earth.</td>
#       <td>[s] Earl_Silverman [r] instance of [o] Human [e]<br> [s] Human [r] model item [o] Joan_of_Arc [e]<br> [s] Human [r] physically interacts with [o] Earth [e]<br></td>
#       <td>[s] Earl_Silverman [r] instance of [o] Human [e]<br> [s] Human [r] model item [o] Joan_of_Arc [e]<br> [s] Human [r] physically interacts with [o] Earth [e]<br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1448</td>
#       <td>Stabroek News is a newspaper from Guyana, founded<br>by David de Caires. It is published in tabloid<br>format, which is a subclass of newspaper and<br>distinct from tabloid journalism.</td>
#       <td>[s] Stabroek_News [r] instance of [o] Newspaper [e]<br> [s] Stabroek_News [r] country [o] Guyana [e]<br> [s] Stabroek_News [r] founded by [o] David_de_Caires [e]<br> [s] Stabroek_News [r] newspaper format [o] Tabloid_(newspaper_format) [e]<br> [s] Tabloid_(newspaper_format) [r] subclass of [o] Newspaper [e]<br> [s] Tabloid_(newspaper_format) [r] different from [o] Tabloid_journalism [e]<br></td>
#       <td>[s] Stabroek_News [r] instance of [o] Newspaper [e]<br> [s] Stabroek_News [r] country of origin [o] Guyana [e]<br> [s] Stabroek_News [r] founded by [o] David_de_Caires [e]<br> [s] Stabroek_News [r] newspaper format [o] Tabloid_(newspaper_format) [e]<br> [s] Tabloid_(newspaper_format) [r] subclass of [o] Newspaper [e]<br> [s] Tabloid_(newspaper_format) [r] different from [o] Tabloid_journalism [e]<br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1456</td>
#       <td>P. J. Molloy, born in Athenry, is a hurling<br>player.</td>
#       <td>[s] P._J._Molloy [r] place of birth
