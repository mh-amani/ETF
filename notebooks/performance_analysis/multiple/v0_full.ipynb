# %% [markdown]
# #### Imports

# %%
project_root_dir = "../../../"

import os
work_dir = os.path.abspath(project_root_dir)

import sys
sys.path.append(project_root_dir)

import wandb
import re

import pandas as pd
from IPython.display import display, HTML
from functools import reduce

import numpy as np

from src.utils import evaluation_helpers
from src.datamodules import IEGenericOutputDataset

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
sns.set_style("ticks")
sns.set_palette("deep")

# %%
# %%html
# <style>
# .dataframe td {
#     white-space: nowrap;
# }
# </style>
# Out:
# <style>
# .dataframe td {
#     white-space: nowrap;
# }
# </style>

# %% [markdown]
# ## The Part to Update

# %%
# Helper for getting the desired wandb run names and wandb paths

# api = wandb.Api()
# entity, project = "epfl-dlab", "SynthIE"  # set to your entity and project 
# runs = api.runs(entity + "/" + project) 
# run_name2wandb_path = {}
# for run in runs:
#     if run.name.startswith('inf_full'):
#         run_name2wandb_path[run.name] = f"{entity}/{project}/{run.id}"
# print(run_name2wandb_path)

# %%
run_name2wandb_path = {'inf_full_v3_datamodule-sdg_code_davinci_002_world-genie_split-test_code_davinci_constraint-R-max_lp-0.8': 'epfl-dlab/SynthIE/86hxtasf', 
'inf_full_v2_datamodule-sdg_code_davinci_002_world-genie_split-test_code_davinci_constraint-R-max_lp-0.8': 'epfl-dlab/SynthIE/x0j4ccka', 
'inf_full_v3_datamodule-rebel_world-genie_split-test_constraint-R-max_lp-0.8': 'epfl-dlab/SynthIE/2x201deo', 
'inf_full_v2_datamodule-rebel_world-genie_split-test_constraint-R-max_lp-0.8': 'epfl-dlab/SynthIE/6tffjiwp'
}

# Useful for the process_results launcher
# print(" ".join(list(run_name2wandb_path.values())))

# %%
#### Which experiments to consider?

# model_id_wandb_run_path_pairs = [("R", "martinj96/SynthIE/izr0vgpw"), ("R+S", "martinj96/SynthIE/2f857wrl"), ("R", "martinj96/SynthIE/3274th6j"), ("R+S", "martinj96/SynthIE/runs/22djwbxk")]
model_id_wandb_run_path_pairs = [("R", wandb_path) if "v2" in run_name else ("R+S", wandb_path) for run_name, wandb_path in run_name2wandb_path.items()][::-1]

#### What to report?

PRESENT_QUANTITATIVE_RESULTS = True
PRESENT_QUALITATIVE_RESULTS = True


# ~~~ Qauntitative results ~~~
metrics = ["triplet_set_precision", "triplet_set_recall", "triplet_set_f1"]
# Used for the confidence interval retrieval from the results.json file
n_bootstrap_samples = 50  # Set to None to present only the corpus level metric (without confidence intervals)
confidence_level = 0.95

metric_name2label = {"triplet_set_precision": "P", "triplet_set_recall": "R", "triplet_set_f1": "F1"}
dataset_name2dataset_label = {"rebel": "REBEL", "sdg_code_davinci_002": "[SDG] Code Davinci"}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# ~~~ Qualitative results ~~~
n_samples = 20
n_predictions_to_show = 1
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ##### Define Experiment ID

# %%
# ~~~ Optional ~~~~
def retrieve_constraint_module_id(hydra_config):
    cm_cfg = hydra_config['model']['constraint_module']

    if cm_cfg == None or cm_cfg == 'None':
        return "free"

    identifier2label = {'genie': 'R-max'}
    return identifier2label.get(cm_cfg['identifier'], cm_cfg['identifier'])

def retrieve_lenght_penalty(hydra_config):
    return hydra_config['model']['hparams_overrides']['inference']['hf_generation_params']['length_penalty']
# ~~~~~~~~~~~~~~~~~~

# The names of these functions should not change    
def get_exp_id(model_id, hydra_config):
    return f"{model_id} -- ({retrieve_constraint_module_id(hydra_config)}) lp_{retrieve_lenght_penalty(hydra_config)} [{dataset_name2dataset_label[retrieve_dataset_name(hydra_config)]}]"

def retrieve_dataset_name(hydra_config):
    return hydra_config['datamodule']['name']

results_df_field2getter = {"LP": retrieve_lenght_penalty, "Constraint": retrieve_constraint_module_id}
barplot_hue_ordering = ['Model', 'LP', 'Constraint']
results_ordering = barplot_hue_ordering

# %% [markdown]
# ## Main Part

# %%
wandb_configs = {}
hydra_configs = {}
abs_exp_dirs = {}

output_datasets = {}
results = {}

exp_id2wandb_run_path = {}
exp_id2model_id = {}

for model_id, wandb_run_path in model_id_wandb_run_path_pairs:
    api = wandb.Api()
    run = api.run(wandb_run_path)
    wandb_config, hydra_config, abs_exp_dir = evaluation_helpers.prepare_data_for_experiment(wandb_run_path, work_dir, print)
    exp_id = get_exp_id(model_id, hydra_config)
    exp_id2wandb_run_path[exp_id] = wandb_run_path
    exp_id2model_id[exp_id] = model_id

    wandb_configs[exp_id], hydra_configs[exp_id], abs_exp_dirs[exp_id] = wandb_config, hydra_config, abs_exp_dir

    # Load predictions data
    data_dir = os.path.join(abs_exp_dirs[exp_id], "predictions")
    output_datasets[exp_id] = IEGenericOutputDataset(data_dir=data_dir, seed=123)

    # Load existing results data
    results[exp_id] = evaluation_helpers.Results(abs_exp_dirs[exp_id])

exp_ids = list(results.keys())
# Out:
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_full_v2_datamodule-rebel_world-genie_split-test_constraint-R-max_lp-0.8/2023-01-11_19-52-23
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_full_v3_datamodule-rebel_world-genie_split-test_constraint-R-max_lp-0.8/2023-01-12_01-42-26
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_full_v2_datamodule-sdg_code_davinci_002_world-genie_split-test_code_davinci_constraint-R-max_lp-0.8/2023-01-12_09-51-04
# Loading the existing results
# Experiment directory already exists: /Users/josifosk/Documents/PhD/SynthIE_main/logs/inference/runs/inf_full_v3_datamodule-sdg_code_davinci_002_world-genie_split-test_code_davinci_constraint-R-max_lp-0.8/2023-01-12_11-54-23
# Loading the existing results

# %%
if PRESENT_QUANTITATIVE_RESULTS:
    metric_label = [metric_name2label[metric_id] for metric_id in metrics]

    # Retrieve information
    results_dfs = []
    for exp_id in exp_id2wandb_run_path.keys():
        curr_results = results[exp_id]
        
        if n_bootstrap_samples is None:
            y = [curr_results.get_corpus_level_metric(metric_id) for metric_id in metrics]
            yerr = None
        else:
            y = []
            yerr = []
            for metric_id in metrics:
                ci = curr_results.get_ci(metric_id, confidence_level, n_bootstrap_samples)
                y.append(ci['mean'])
                yerr.append((ci['mean'] - ci['lower'], ci['upper'] - ci['mean']))

            yerr = np.array(yerr).T

        # create a datataframe
        df = pd.DataFrame({'Metric': metric_label, 'Score': y, 'ci_score_lower': yerr[0, :], 'ci_score_upper': yerr[1, :]})
        
        # required fields
        df['Exp_ID'] = [exp_id] * df.shape[0]
        df['Dataset'] = [retrieve_dataset_name(hydra_configs[exp_id])] * df.shape[0]
        df['Model'] = [exp_id2model_id[exp_id]] * df.shape[0]

        # optional fields
        if results_df_field2getter is not None:
            for field_name, getter in results_df_field2getter.items():
                df[field_name] = [getter(hydra_configs[exp_id])] * df.shape[0]
        results_dfs.append(df)

    results_df = pd.concat(results_dfs, axis=0)
    
    # Massage the data
    dataset_names = results_df['Dataset'].unique()

    per_dataset_results_long = {}
    per_dataset_results_wide = {}

    per_dataset_results_ci_lower = {}
    per_dataset_results_ci_upper = {}

    for dataset_name in dataset_names:
        dataset_long_df = results_df[results_df['Dataset'] == dataset_name].copy()
        # set the error term to the average of the empirical lower and upper confidence interval delta
        # dataset_long_df['Error'] = ((dataset_long_df['ci_score_lower'] + dataset_long_df['ci_score_upper']) / 2)
        # dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + ' ± ' + (dataset_long_df['Error']*100).round(2).astype(str)
        dataset_long_df['Score_with_ci'] = (dataset_long_df['Score']*100).round(2).astype(str) + " [" + ((dataset_long_df['Score']-dataset_long_df['ci_score_lower'])*100).round(2).astype(str) + ", " + ((dataset_long_df['Score'] + dataset_long_df['ci_score_upper'])*100).round(2).astype(str) + "]"
        per_dataset_results_long[dataset_name] = dataset_long_df

        pivot_index = ['Model']
        if results_df_field2getter is not None:
            pivot_index.extend(list(results_df_field2getter.keys()))
        dataset_wide_df = dataset_long_df.pivot_table(index=pivot_index, columns='Metric', values='Score_with_ci', aggfunc=lambda x: ' '.join(x))
        dataset_wide_df = dataset_wide_df[['P', 'R', 'F1']]
        per_dataset_results_wide[dataset_name] = dataset_wide_df

    results_wide_df = pd.concat(per_dataset_results_wide.values(), keys=per_dataset_results_wide.keys(), names=['Dataset'], axis=1)
    results_wide_df = results_wide_df.sort_index(axis=0, level=results_ordering)
    results_wide_df.columns = pd.MultiIndex.from_tuples([(dataset_name2dataset_label[dataset_name], metric) for dataset_name, metric in results_wide_df.columns.values], names=['Dataset', f'Metric [{int(confidence_level*100)}% CI]'])
    
    display(results_wide_df)
# Out:
# Dataset                              REBEL                        \
# Metric [95% CI]                          P                     R
# Model LP  Constraint
# R     0.8 R-max       77.37 [77.07, 77.72]  77.49 [77.23, 77.83]
# R+S   0.8 R-max       12.19 [12.05, 12.31]  25.05 [24.81, 25.32]
#
# Dataset                                       [SDG] Code Davinci  \
# Metric [95% CI]                         F1                     P
# Model LP  Constraint
# R     0.8 R-max       77.43 [77.18, 77.76]  12.49 [12.15, 12.86]
# R+S   0.8 R-max        16.4 [16.23, 16.55]    73.3 [72.9, 73.77]
#
# Dataset
# Metric [95% CI]                          R                    F1
# Model LP  Constraint
# R     0.8 R-max          3.24 [3.14, 3.34]      5.15 [4.99, 5.3]
# R+S   0.8 R-max       61.42 [61.01, 61.76]  66.83 [66.44, 67.23]

# %%
# Figure for the table above
if PRESENT_QUANTITATIVE_RESULTS:
    capsize = 0

    # get a subplot for each dataset
    figsize = (10, 7 * len(dataset_names))
    fig, axes = plt.subplots(len(dataset_names), 1, figsize=figsize, sharex=True, sharey=True)
    
    if len(dataset_names) == 1:
        axes = [axes]

    for ax, dataset_name in zip(axes, dataset_names):
        dataset_results_long_df = per_dataset_results_long[dataset_name]
        # sort the dataframe accoring to the Constraint, Model and LP
        if barplot_hue_ordering is not None:
            dataset_results_long_df = dataset_results_long_df.sort_values(by=barplot_hue_ordering)
        dataset_results_long_df.reset_index(inplace=True, drop=True)

        hue_order = dataset_results_long_df['Exp_ID'].drop_duplicates().values.tolist()
        order = ['P', 'R', 'F1']
        sns.barplot(ax=ax, data=dataset_results_long_df, x='Metric', y="Score", hue='Exp_ID', edgecolor="black", palette='deep', order=order, hue_order=hue_order)

        ax.set_title(dataset_name2dataset_label[dataset_name])
        ax.set_ylabel("Score")
        ax.set_ylim(0,1)
        if ax != axes[0]:
            ax.set_xlabel("Metric")
        else:
            ax.set_xlabel("")

        # make the legend a bit more compact and remove the box around the legend
        # handles, labels = ax.get_legend_handles_labels()
        ax.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1, frameon=False)

        if 'ci_score_lower' in dataset_results_long_df.columns:
            x_coords = [p.get_x() + 0.5 * p.get_width() for p in ax.patches]
            y_coords = [p.get_height() for p in ax.patches]

            dataset_results_long_df.Exp_ID = pd.Categorical(dataset_results_long_df.Exp_ID, categories=hue_order, ordered=True)
            dataset_results_long_df.Metric = pd.Categorical(dataset_results_long_df.Metric, categories=order, ordered=True)
            error = np.stack([dataset_results_long_df.sort_values(by=['Exp_ID', 'Metric'])['ci_score_lower'].values, dataset_results_long_df.sort_values(by=['Exp_ID', 'Metric'])['ci_score_upper'].values])
            ax.errorbar(x=x_coords, y=y_coords, yerr=error, fmt="none", color="black", capsize=capsize, zorder=100000)

# %%
def get_predictions_df(exp_ids):
        random_ids = None

        pred_dfs = []

        for exp_id in exp_ids:
            output_dataset = output_datasets[exp_id]

            
            if random_ids is None:
                random_indices = np.random.RandomState(seed).choice(len(output_dataset),  min([n_samples, len(output_dataset)]), replace=False)
                random_ids = set([output_dataset.data[i]['id'] for i in random_indices])

            random_sample = [output_dataset.data[i] for i in random_indices if output_dataset.data[i]['id'] in random_ids]

            ids = [sample['id'] for sample in random_sample]
            inputs = [sample['input'] for sample in random_sample]
            targets = [sample['target'] for sample in random_sample]
            predictions = [sample['prediction'][0] if n_predictions_to_show == 1 else sample['prediction'][:n_predictions_to_show] for sample in random_sample]

            df = pd.DataFrame(list(zip(ids, inputs, targets, predictions)), columns=['id', 'input', 'target', f'prediction_{exp_id}'])
            pred_dfs.append(df)

        predictions_df = reduce(lambda  left,right: pd.merge(left,right,on=['id', 'input', 'target'], how='inner', ), pred_dfs)
        predictions_df.sort_values(by=['id'], inplace=True)
        assert(predictions_df.shape[0] == len(random_ids))
        return predictions_df


def wrap_df_text(df, input_max_col):
    tdf = df.copy()
    tdf['input'] = tdf['input'].str.wrap(input_max_col)
    tdf['target'] = tdf['target'].str.replace("\[e\]|\[et\]", "[e]\\n", regex=True)

    for col in tdf.columns:
        if col.startswith("prediction"):
            if type(tdf[col][0]) == str:
                tdf[col] = tdf[col].str.replace("\[e\]|\[et\]", "[e]\\n", regex=True)
            else:
                tdf[col] = tdf[col].apply(lambda x: "\\n".join([re.sub("\[e\]|\[et\]", "[e]\\n", p) for p in x]))

    display(HTML(tdf.to_html().replace("\\n","<br>")))


if PRESENT_QUALITATIVE_RESULTS:
    seed = 123

    # get the dataset_name for each experiment
    dataset_names = list([retrieve_dataset_name(hydra_configs[exp_id]) for exp_id in exp_ids])

    for dataset_name in set(dataset_names):
        print(f"~~~~ {dataset_name2dataset_label[dataset_name]} ~~~~")
        exp_ids_to_visualize = [exp_id for exp_id, exp_dataset_name in zip(exp_ids, dataset_names) if exp_dataset_name  == dataset_name]
        print(exp_ids_to_visualize)
        predictions_df = get_predictions_df(exp_ids_to_visualize)

        with pd.option_context('display.max_rows', None, 'display.max_columns', None, "display.expand_frame_repr", False, 'display.max_colwidth', None, 'display.width', None):        
            wrap_df_text(predictions_df, 50)
# Out:
# ~~~~ REBEL ~~~~
# ['R -- (R-max) lp_0.8 [REBEL]', 'R+S -- (R-max) lp_0.8 [REBEL]']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>input</th>
#       <th>target</th>
#       <th>prediction_R -- (R-max) lp_0.8 [REBEL]</th>
#       <th>prediction_R+S -- (R-max) lp_0.8 [REBEL]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19</th>
#       <td>11651</td>
#       <td>The Roman Catholic Diocese of Savannah is an<br>ecclesiastical territory or diocese of the Roman<br>Catholic Church in the southern United States<br>comprising 90 of the southern counties of the<br>state of Georgia.</td>
#       <td>[s] Roman_Catholic_Diocese_of_Savannah [r] country [o] United_States [e]<br> [s] Georgia_(U.S._state) [r] country [o] United_States [e]<br> [s] Georgia_(U.S._state) [r] instance of [o] U.S._state [e]<br></td>
#       <td>[s] Roman_Catholic_Diocese_of_Savannah [r] country [o] United_States [e]<br> [s] Georgia_(U.S._state) [r] country [o] United_States [e]<br></td>
#       <td>[s] Roman_Catholic_Diocese_of_Savannah [r] Catholic rite [o] Roman_Rite [e]<br> [s] Roman_Catholic_Diocese_of_Savannah [r] language used [o] English_language [e]<br> [s] Roman_Catholic_Diocese_of_Savannah [r] country [o] United_States [e]<br> [s] Roman_Rite [r] used by [o] Latin_Church [e]<br></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>17865</td>
#       <td>Welsh Mountain sheep (, ) are small, hardy sheep<br>from the higher parts of the Welsh mountains.</td>
#       <td>[s] Welsh_Mountain_sheep [r] subclass of [o] Sheep [e]<br></td>
#       <td>[s] Welsh_Mountain_sheep [r] subclass of [o] Sheep [e]<br></td>
#       <td>[s] Welsh_Mountain_sheep [r] parent taxon [o] Sheep [e]<br> [s] Welsh_Mountain_sheep [r] country of origin [o] Wales [e]<br> [s] Welsh_Mountain_sheep [r] subclass of [o] Sheep [e]<br></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>18502</td>
#       <td>WISE J080822.18-644357.3, also called J0808, is a<br>45 Myr old star system in the Carina constellation<br>with a circumstellar debris disk orbiting an<br>M-type red dwarf about 331 lightyears from Earth.</td>
#       <td>[s] WISE_J080822.18-644357.3 [r] instance of [o] Circumstellar_disc [e]<br> [s] Star [r] part of [o] Star_system [e]<br> [s] Debris_disk [r] subclass of [o] Circumstellar_disc [e]<br></td>
#       <td>[s] Carina_(constellation) [r] instance of [o] Constellation [e]<br></td>
#       <td>[s] WISE_J080822.18-644357.3 [r] constellation [o] Carina_(constellation) [e]<br> [s] WISE_J080822.18-644357.3 [r] instance of [o] Star [e]<br> [s] Carina_(constellation) [r] described by source [o] Internetowa_encyklopedia_PWN [e]<br></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>19510</td>
#       <td>Sentebale is a registered charity, founded in 2006<br>by Prince Harry, Duke of Sussex of the British<br>Royal Family and Prince Seeiso, Principal Chief of<br>Matsieng of the Basotho Royal Family.</td>
#       <td>[s] Prince_Harry,_Duke_of_Sussex [r] part of [o] British_royal_family [e]<br> [s] British_royal_family [r] country [o] United_Kingdom [e]<br></td>
#       <td>[s] Prince_Harry,_Duke_of_Sussex [r] part of [o] British_royal_family [e]<br></td>
#       <td>[s] Southeastern_League [r] legal form [o] Charitable_organization [e]<br> [s] Southeastern_League [r] founded by [o] Prince_Harry,_Duke_of_Sussex [e]<br> [s] Southeastern_League [r] instance of [o] Nonprofit_organization [e]<br> [s] Charitable_organization [r] field of work [o] Charity_(practice) [e]<br> [s] Prince_Harry,_Duke_of_Sussex [r] honorific prefix [o] Royal_Highness [e]<br> [s] Prince_Harry,_Duke_of_Sussex [r] honorific prefix [o] Royal_Highness [e]<br> [s] Prince_Harry,_Duke_of_Sussex [r] honorific prefix [o] Royal_Highness [e]<br></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>21546</td>
#       <td>Aldershot Garrison, also known as Aldershot<br>Military Town, is a major garrison in South East<br>England, located between Aldershot and Farnborough<br>in Hampshire.</td>
#       <td>[s] Aldershot_Garrison [r] instance of [o] Garrison [e]<br></td>
#       <td>[s] Aldershot_Garrison [r] instance of [o] Garrison [e]<br></td>
#       <td>[s] Aldershot_Garrison [r] named after [o] Aldershot [e]<br> [s] Aldershot_Garrison [r] located in the administrative territorial entity [o] South_East_England [e]<br> [s] Aldershot_Garrison [r] country [o] United_Kingdom [e]<br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>24377</td>
#       <td>Çamlıgöze Dam is an embankment dam on the Kelkit<br>River in Sivas Province, Turkey.</td>
#       <td>[s] Çamlıgöze_Dam [r] country [o] Turkey [e]<br> [s] Kelkit_River [r] country [o] Turkey [e]<br> [s] Sivas_Province [r] country [o] Turkey [e]<br></td>
#       <td>[s] amlgöze_Dam [r] instance of [o] Embankment_dam [e]<br> [s] amlgöze_Dam [r] country [o] Turkey [e]<br> [s] Kelkit_River [r] country [o] Turkey [e]<br> [s] Sivas_Province [r] country [o] Turkey [e]<br></td>
#       <td>[s] amlgöze_Dam [r] located on terrain feature [o] Kelkit_River [e]<br> [s] amlgöze_Dam [r] located in the administrative territorial entity [o] Sivas_Province [e]<br> [s] amlgöze_Dam [r] instance of [o] Embankment_dam [e]<br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>24557</td>
#       <td>In 1938 he began signing his pictures using the<br>Lithuanian version of his name (he had taken<br>Lithuanian citizenship in 1920).</td>
#       <td>[s] University_of_Cape_Town [r] country [o] South_Africa [e]<br></td>
#       <td>[s] Vilnius [r] country [o] Lithuania [e]<br> [s] Lithuania [r] capital [o] Vilnius [e]<br></td>
#       <td>[s] Vilnius [r] official language [o] Lithuanian_language [e]<br> [s] Vilnius [r] described by source [o] Brockhaus_and_Efron_Encyclopedic_Dictionary [e]<br> [s] Vilnius [r] described by source [o] Brockhaus_and_Efron_Encyclopedic_Dictionary [e]<br> [s] Lithuanian_language [r] indigenous to [o] Lithuania [e]<br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>24854</td>
#       <td>The Services football team is an Indian football<br>team representing the Indian defence services in<br>the Santosh Trophy.</td>
#       <td>[s] Services_football_team [r] country [o] India [e]<br></td>
#       <td>[s] Santosh_Trophy [r] country [o] India [e]<br></td>
#       <td>[s] Services_football_team [r] sport [o] Association_football [e]<br> [s] Services_football_team [r] country [o] India [e]<br> [s] Association_football [r] regulated by [o] FIFA [e]<br> [s] Association_football [r] practiced by [o] Football_player [e]<br></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>27382</td>
#       <td>Polkovnik Dyakovo is a village in the municipality<br>of Krushari, in Dobrich Province, in northeastern<br>Bulgaria.</td>
#       <td>[s] Krushari [r] country [o] Bulgaria [e]<br> [s] Dobrich_Province [r] country [o] Bulgaria [e]<br></td>
#       <td>[s] Krushari [r] country [o] Bulgaria [e]<br> [s] Dobrich_Province [r] country [o] Bulgaria [e]<br></td>
#       <td>[s] Krushari [r] located in time zone [o] UTC+01:00 [e]<br> [s] Krushari [r] located in time zone [o] UTC+02:00 [e]<br> [s] Krushari [r] country [o] Bulgaria [e]<br> [s] Krushari [r] located in the administrative territorial entity [o] Dobrich_Province [e]<br> [s] Krushari [r] instance of [o] Municipalities_of_Bulgaria [e]<br> [s] UTC+01:00 [r] said to be the same as [o] Central_European_Time [e]<br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>29679</td>
#       <td>The Captaincy General of Yucatán () was an<br>administrative district of colonial Spain, created<br>in 1617 to provide more autonomy for the Yucatán<br>Peninsula, previously ruled directly by a simple<br>governor under the jurisdiction of Audiencia of<br>Mexico.</td>
#       <td>[s] Captaincy_General_of_Yucatán [r] country [o] Spanish_Empire [e]<br> [s] Spanish_colonization_of_the_Americas [r] part of [o] Spanish_Empire [e]<br> [s] Real_Audiencia_of_Mexico [r] country [o] Spanish_Empire [e]<br></td>
#       <td>[s] Captaincy_General_of_Yucatán [r] country [o] Spanish_Empire [e]<br></td>
#       <td>[s] Captaincy_General_of_Yucatán [r] basic form of government [o] Constitutiona
# ~~~~ [SDG] Code Davinci ~~~~
# ['R -- (R-max) lp_0.8 [[SDG] Code Davinci]', 'R+S -- (R-max) lp_0.8 [[SDG] Code Davinci]']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>input</th>
#       <th>target</th>
#       <th>prediction_R -- (R-max) lp_0.8 [[SDG] Code Davinci]</th>
#       <th>prediction_R+S -- (R-max) lp_0.8 [[SDG] Code Davinci]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5176</td>
#       <td>Black locust (Robinia pseudoacacia) is a nitrogen-<br>fixing tree that is used as fodder, and is<br>invasive in Shanghai.</td>
#       <td>[s] Robinia_pseudoacacia [r] invasive to [o] Shanghai [e]<br> [s] Robinia_pseudoacacia [r] use [o] Fodder [e]<br> [s] Robinia_pseudoacacia [r] parent taxon [o] Robinia [e]<br> [s] Robinia_pseudoacacia [r] has quality [o] Nitrogen_fixation [e]<br></td>
#       <td>[s] Fodder [r] part of [o] Tree [e]<br></td>
#       <td>[s] Robinia_pseudoacacia [r] invasive to [o] Shanghai [e]<br> [s] Robinia_pseudoacacia [r] this taxon is source of [o] Nitrogen [e]<br> [s] Robinia_pseudoacacia [r] taxon rank [o] Species [e]<br> [s] Robinia_pseudoacacia [r] use [o] Fodder [e]<br></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>53669</td>
#       <td>Aspirin may prevent heart attacks, and it is an<br>essential medicine. It interacts with<br>acetazolamide and chlorpropamide, and it is found<br>in liquorice. It physically interacts with PTGS1.<br>Myocardial infarction affects the coronary<br>arteries.</td>
#       <td>[s] Aspirin [r] may prevent [o] Myocardial_infarction [e]<br> [s] Aspirin [r] significant drug interaction [o] Acetazolamide [e]<br> [s] Aspirin [r] physically interacts with [o] PTGS1 [e]<br> [s] Aspirin [r] significant drug interaction [o] Chlorpropamide [e]<br> [s] Aspirin [r] found in taxon [o] Liquorice [e]<br> [s] Aspirin [r] instance of [o] Essential_medicines [e]<br> [s] Myocardial_infarction [r] afflicts [o] Coronary_arteries [e]<br></td>
#       <td>[s] Aspirin [r] instance of [o] Medication [e]<br></td>
#       <td>[s] Aspirin [r] may prevent [o] Myocardial_infarction [e]<br> [s] Aspirin [r] physically interacts with [o] Acetazolamide [e]<br> [s] Aspirin [r] physically interacts with [o] Chlorpropamide [e]<br> [s] Aspirin [r] found in taxon [o] Liquorice [e]<br> [s] Aspirin [r] instance of [o] Essential_medicines [e]<br> [s] Aspirin [r] physically interacts with [o] PTGS1 [e]<br> [s] Myocardial_infarction [r] afflicts [o] Coronary_arteries [e]<br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>60599</td>
#       <td>The unary numeral system is a base-1 numeral<br>system. It is followed by the binary number<br>system, which consists of base-2 digits. The digit<br>"1" is defined in the Explanatory Dictionary of<br>the Living Great Russian Language as "1, one,<br>single, sole, sole and unique". It is also defined<br>as "0.999..." and as a dimensionless quantity. It<br>is not to be confused with AD 1. The binary number<br>system is a subclass of the binary code.</td>
#       <td>[s] Unary_numeral_system [r] radix [o] 1 [e]<br> [s] Unary_numeral_system [r] followed by [o] Binary_number [e]<br> [s] 1 [r] described by source [o] Explanatory_Dictionary_of_the_Living_Great_Russian_Language [e]<br> [s] 1 [r] said to be the same as [o] 0.999... [e]<br> [s] 1 [r] measured physical quantity [o] Dimensionless_quantity [e]<br> [s] 1 [r] different from [o] AD_1 [e]<br> [s] Binary_number [r] subclass of [o] Binary_code [e]<br></td>
#       <td>[s] Binary_number [r] subclass of [o] Binary_code [e]<br></td>
#       <td>[s] Unary_numeral_system [r] radix [o] 1 [e]<br> [s] Unary_numeral_system [r] followed by [o] Binary_number [e]<br> [s] 1 [r] measured physical quantity [o] Dimensionless_quantity [e]<br> [s] 1 [r] described by source [o] Explanatory_Dictionary_of_the_Living_Great_Russian_Language [e]<br> [s] 1 [r] different from [o] AD_1 [e]<br> [s] Binary_number [r] subclass of [o] Binary_code [e]<br></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>189613</td>
#       <td>Giancarla Trevisan is an American with Italian<br>citizenship who was born in Laguna Niguel,<br>California. She competes for Italy in athletics.</td>
#       <td>[s] Giancarla_Trevisan [r] country for sport [o] Italy [e]<br> [s] Giancarla_Trevisan [r] sport [o] Sport_of_athletics [e]<br> [s] Giancarla_Trevisan [r] languages spoken, written or signed [o] Italian_language [e]<br> [s] Giancarla_Trevisan [r] instance of [o] Human [e]<br> [s] Giancarla_Trevisan [r] place of birth [o] Laguna_Niguel,_California [e]<br> [s] Giancarla_Trevisan [r] country of citizenship [o] United_States [e]<br></td>
#       <td>[s] 2019_World_Athletics_Championships_–_Women's_5000_metres [r] part of [o] 2019_World_Athletics_Championships [e]<br></td>
#       <td>[s] Giancarla_Trevisan [r] country of citizenship [o] United_States [e]<br> [s] Giancarla_Trevisan [r] place of birth [o] Laguna_Niguel,_California [e]<br> [s] Giancarla_Trevisan [r] country of citizenship [o] Italy [e]<br> [s] Giancarla_Trevisan [r] sport [o] Sport_of_athletics [e]<br></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>282804</td>
#       <td>1729 is a composite number, the product of two<br>prime numbers: 7 and 13. It is also the sum of two<br>cubes: 1^3 + 12^3 = 9 + 1728 = 1729. It is a<br>taxicab number and is called a Hardy–Ramanujan<br>number after an anecdote of the British<br>mathematician G. H. Hardy when he visited Indian<br>mathematician Srinivasa Ramanujan in hospital. The<br>story goes that Hardy remarked that the number<br>seemed to him dull and uninteresting. Ramanujan<br>replied, "No, Hardy! No, Hardy! It is a very<br>interesting number. It is the smallest number<br>expressible as the sum of two cubes in two<br>different ways."</td>
#       <td>[s] 1729_(number) [r] prime factor [o] 7 [e]<br> [s] 1729_(number) [r] prime factor [o] 13_(number) [e]<br> [s] 1729_(number) [r] instance of [o] Composite_number [e]<br> [s] 1729_(number) [r] instance of [o] Taxicab_number [e]<br> [s] 1729_(number) [r] instance of [o] Natural_number [e]<br> [s] 7 [r] prime factor [o] 7 [e]<br> [s] 7 [r] described by source [o] Brockhaus_and_Efron_Encyclopedic_Dictionary [e]<br></td>
#       <td>[s] 1729_(number) [r] instance of [o] Taxicab_number [e]<br></td>
#       <td>[s] 1729_(number) [r] prime factor [o] 7 [e]<br> [s] 1729_(number) [r] prime factor [o] 13_(number) [e]<br> [s] 1729_(number) [r] described by source [o] Brockhaus_and_Efron_Encyclopedic_Dictionary [e]<br> [s] 1729_(number) [r] instance of [o] Composite_number [e]<br> [s] 1729_(number) [r] instance of [o] Taxicab_number [e]<br> [s] 7 [r] prime factor [o] 7 [e]<br></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>430883</td>
#       <td>Hydrogen was discovered in the United Kingdom by<br>Henry Cavendish, who named it after water. It is<br>the lightest element. Its antiparticle is called<br>antihydrogen.</td>
#       <td>[s] Hydrogen [r] antiparticle [o] Antihydrogen [e]<br> [s] Hydrogen [r] named after [o] Water [e]<br> [s] Hydrogen [r] location of discovery [o] United_Kingdom [e]<br> [s] Hydrogen [r] discoverer or inventor [o] Henry_Cavendish [e]<br> [s] Hydrogen [r] described by source [o] Encyclopædia_Britannica_Eleventh_Edition [e]<br> [s] Antihydrogen [r] antiparticle [o] Hydrogen [e]<br></td>
#       <td>[s] Hydrogen [r] instance of [o] Chemical_element [e]<br></td>
#       <td>[s] Hydrogen [r] antiparticle [o] Antihydrogen [e]<br> [s] Hydrogen [r] location of discovery [o] United_Kingdom [e]<br> [s] Hydrogen [r] discoverer or inventor [o] Henry_Cavendish [e]<br> [s] Hydrogen [r] named after [o] Water [e]<br></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>448106</td>
#       <td>Alexandre Lacoste was a Conservative politician in<br>Quebec, Canada. He was born in Montreal, and died<br>there. He was married to Marie-Louise Lacoste. He<br>was a Queen's Counsel.</td>
#       <td>[s] Alexandre_Lacoste [r] honorific suffix [o] Queen's_Counsel [e]<br> [s] Alexandre_Lacoste [r] spouse [o] Marie-Louise_Lacoste [e]<br> [s] Alexandre_Lacoste [r] member of political party [o] Conservative_Party_of_Canada_(1867–194
