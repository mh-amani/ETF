# %%
import json
import os
from typing import Union

# %%
# Suggestions: (i) name the file in the top level directory "summary.json"; (ii) make sure that it only contains "succesfull" runs; (iii) update the extention of the predictions file to .jsonl

def read_experiment_summaries(path):
    with open(path, "r") as f:
        data = json.load(f)
    return data

def read_predictions(path):
    with open(path, "r") as f:
        data = [json.loads(line) for line in f.readlines()]
    return data

def get_max_len(triplets, field):
    return max([len(t[field]['name']) for t in triplets])

def get_triplets_sequence(triplets):
    max_subject_len = get_max_len(triplets, "subject")
    max_relation_len = get_max_len(triplets, "relation")
    max_object_len = get_max_len(triplets, "object")

    return "\n".join([f"{t['subject']['name']: <{max_subject_len}} ~~~ {t['relation']['name']: <{max_relation_len}} ~~~ {t['object']['name']: <{max_object_len}}" for t in triplets])

def get_triplets_API_format(triplets):
    return " ".join([f"(\"subject\": {t['subject']['name']}, \"relation\": {t['relation']['name']}, \"object\": {t['object']['name']})" for t in triplets])

def get_textual_sequences(model_completions, num_completions_to_show: int):
    if num_completions_to_show  == 1:
        return model_completions[0]
    else:
        return "\n".join(model_completions[:num_completions_to_show])

def visualize_predictions_for_instance(prediction_obj, show_triplets: bool, num_completions_to_show: int, show_api_formatted_triplets: bool):
    if show_triplets:
        print(f"{'~' * 30} Triplets {'~' * 30}")
        print(get_triplets_sequence(prediction_obj["triplet_set"]))
        print()

    if show_api_formatted_triplets:
        print(f"{'~' * 30} Triplets {'~' * 30}")
        print(get_triplets_API_format(prediction_obj["triplet_set"]))
        print()

    
    if num_completions_to_show > 0:
        print(f"{'~' * 30} Text {'~' * 30}")
        print(get_textual_sequences(prediction_obj["model_completions"], num_completions_to_show))
        print()

def get_id(pred_object):
    return (pred_object['extra-information']['dataset-id'], pred_object['extra-information']['dataset'])

def get_ordering(predictions):
    idx2id = {idx:get_id(p) for idx, p in enumerate(predictions)}
    id2idx = {v:k for k, v in idx2id.items()}
    return dict({"id2idx": id2idx, "idx2id": idx2id})

def visualize_predictions_for_experiment(path_to_hps_logs, show_triplets: bool, num_completions_to_show: int, debug_k: Union[int, None] = None, show_api_formatted_triplets: bool = False, show_problem: Union[int, None] = None):
    path_to_summary_file = os.path.join(path_to_hps_logs, "hps_synthie_small_results.json")
    experiment_summaries = read_experiment_summaries(path_to_summary_file)
    ordering_mapping = None

    for exp_idx, exp_metadata in enumerate(experiment_summaries):
        predictions = read_predictions(os.path.join(path_to_hps_logs, exp_metadata["result_filepath"]))
        if ordering_mapping is None:
            ordering_mapping = get_ordering(predictions)
            idx2id = ordering_mapping["idx2id"]
        
        for i in range(len(predictions)):
            if show_problem is not None:
                if i != show_problem:
                    continue
                
            if debug_k is not None:
                if i >= debug_k:
                    break
            
            id = idx2id[i]
            found_id = False
            for _, sample in enumerate(predictions):
                if get_id(sample) != id:
                    continue
                found_id = True
                print(f"{'=' * 30} [Parameter config {exp_idx}] Sample {i} -- ID: {id} {'=' * 30}")
                visualize_predictions_for_instance(sample, show_triplets=show_triplets, num_completions_to_show=num_completions_to_show, show_api_formatted_triplets=show_api_formatted_triplets)
                print()
            assert found_id, f"Could not find the sample with ID {id} in predictions"
    
    return ordering_mapping

# %%
path_to_hps_logs = "/dlabdata1/josifosk/SynthIE_main/data/hps_results/hps_synthie_small"
show_triplets = True
num_completions_to_show = 1
debug_k = None

visualize_predictions_for_experiment(path_to_hps_logs, show_triplets, num_completions_to_show, debug_k, show_api_formatted_triplets=False)
# Out:
# ============================== [Parameter config 0] Sample 0 -- ID: (41948, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Chief_Minister_of_the_Australian_Capital_Territory ~~~ officeholder              ~~~ Andrew_Barr
# Andrew_Barr                                        ~~~ position held             ~~~ Chief_Minister_of_the_Australian_Capital_Territory
# Andrew_Barr                                        ~~~ member of political party ~~~ Australian_Labor_Party_(Australian_Capital_Territory_Branch)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Government of the Australian Capital Territory, also referred to as the Australian Capital Territory Government or ACT Government, is the executive authority of the Australian Capital Territory, one of the territories of Australia. The leader of the party or coalition with the confidence of the Australian Capital Territory Legislative Assembly forms Government.
#
#
# ============================== [Parameter config 0] Sample 1 -- ID: (35685, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Seremban Line is a KTM Komuter train line in Malaysia operated by Keretapi Tanah Melayu.
#
#
# ============================== [Parameter config 0] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Democrats for Andorra (Demòcrates per Andorra, DA) is a political party in Andorra.
#
#
# ============================== [Parameter config 0] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born Rome, Italy, 26 February 1960) is an Italian politician and Member of the European Parliament for the Union of the Centre, part of the European People's Party and sits on the European Parliament's Committee on Transport and Tourism.
#
#
# ============================== [Parameter config 0] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra ja kaunis Kirstin (English: The Squire and the Beautiful Kirstin) is a novel by Finnish author Kaari Utrio.
#
#
# ============================== [Parameter config 0] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Scenic Daylight () was a passenger train operated by the New Zealand Railways Department (NZR) between Auckland and Wellington from 1960 to 1971.
#
#
# ============================== [Parameter config 0] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In 1979, L'Amour wrote The Sacketts and The Legend of the Golden Gun, which were published posthumously.
#
#
# ============================== [Parameter config 0] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk Mazowiecki County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 0] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's Tome is an encyclical letter sent by Pope Leo I to Flavian of Constantinople in the year 449.
#
#
# ============================== [Parameter config 0] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Queensland (abbreviated as Qld) is the second-largest and third-most populous state in Australia.
#
#
# ============================== [Parameter config 0] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The science became established in the 18th century as a result of Georges Cuvier's work on comparative anatomy, and developed rapidly in the 19th century. The term itself originates from Greek παλαιός, "palaios", "old, ancient", ὄν, "on" (gen. "ontos"), "being, creature", and λόγος, "logos", "speech, thought, study".
#
#
# ============================== [Parameter config 0] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 0] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini Harbour is a harbour in Mombasa, Kenya.
#
#
# ============================== [Parameter config 1] Sample 0 -- ID: (41948, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Chief_Minister_of_the_Australian_Capital_Territory ~~~ officeholder              ~~~ Andrew_Barr
# Andrew_Barr                                        ~~~ position held             ~~~ Chief_Minister_of_the_Australian_Capital_Territory
# Andrew_Barr                                        ~~~ member of political party ~~~ Australian_Labor_Party_(Australian_Capital_Territory_Branch)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The current Chief Minister is Andrew Barr of the Australian Labor Party, who was elected on 11 December 2014.
#
#
# ============================== [Parameter config 1] Sample 1 -- ID: (35685, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Seremban Line is a KTM Komuter train service in Malaysia that runs between Seremban and Batang Melaka.
#
#
# ============================== [Parameter config 1] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Democrats for Andorra (Demòcrates per Andorra, DA) is a centre-right political party in Andorra.
#
#
# ============================== [Parameter config 1] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born in Rome, Italy) is an Italian politician and member of the Union of the Centre.
#
#
# ============================== [Parameter config 1] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra ja kaunis Kirstin (English: "The Squire and the Beautiful Kirstin") is a novel by Kaari Utrio.
#
#
# ============================== [Parameter config 1] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Scenic Daylight was a New Zealand passenger train that ran between Auckland and Wellington from 1960 to 2001.
#
#
# ============================== [Parameter config 1] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) is a Western novel by Louis L'Amour, the third in his Sackett series.
#
#
# ============================== [Parameter config 1] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk Mazowiecki County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 1] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's Tome is a letter written by Pope Leo I to Flavian of Constantinople in 449.
#
#
# ============================== [Parameter config 1] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Australian state of Queensland has a number of national parks.
#
#
# ============================== [Parameter config 1] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The genitive case (abbreviated gen), in grammar, is the grammatical case that marks a word, usually a noun, as modifying another word, also usually a noun.
#
#
# ============================== [Parameter config 1] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 1] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini Harbour is the main seaport of Mombasa, Kenya.
#
#
# ============================== [Parameter config 2] Sample 0 -- ID: (41948, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Chief_Minister_of_the_Australian_Capital_Territory ~~~ officeholder              ~~~ Andrew_Barr
# Andrew_Barr                                        ~~~ position held             ~~~ Chief_Minister_of_the_Australian_Capital_Territory
# Andrew_Barr                                        ~~~ member of political party ~~~ Australian_Labor_Party_(Australian_Capital_Territory_Branch)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Government of the Australian Capital Territory, also referred to as the Australian Capital Territory Government or ACT Government, is the executive authority of the Australian Capital Territory, one of the territories of Australia. The leader of the party or coalition with the confidence of the Australian Capital Territory Legislative Assembly forms Government.
#
#
# ============================== [Parameter config 2] Sample 1 -- ID: (35685, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Labu railway station is a KTM Komuter train station located at and named after the small town of Labu, Negeri Sembilan, Malaysia.
#
#
# ============================== [Parameter config 2] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Democrats for Andorra (Catalan: Demòcrates per Andorra) is a centre-right political party in Andorra.
#
#
# ============================== [Parameter config 2] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born 3 November 1959 in Rome, Italy) is an Italian politician and a member of the Union of the Centre (UdC).
#
#
# ============================== [Parameter config 2] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra ja kaunis Kirstin is a novel by Kaari Utrio.
#
#
# ============================== [Parameter config 2] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# New Zealand Railways Road Services (NZRRS) ran a fleet of Scenic Daylight railcars, which were introduced in 1960 between Auckland and Wellington via the North Island Main Trunk.
#
#
# ============================== [Parameter config 2] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun (1979)
#
#
# ============================== [Parameter config 2] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk Mazowiecki County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 2] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's Tome is an epistle written by Pope Leo I to Flavian of Constantinople in the year 449.
#
#
# ============================== [Parameter config 2] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Queensland (abbreviated as Qld) is the second-largest and third-most populous state in the Commonwealth of Australia.
#
#
# ============================== [Parameter config 2] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The genitive case, which is used extensively in the Greek of the New Testament, has all but disappeared in modern Greek.
#
#
# ============================== [Parameter config 2] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 2] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini Harbour, in Mombasa, is the largest harbour in Kenya.
#
#
# ============================== [Parameter config 3] Sample 0 -- ID: (41948, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Chief_Minister_of_the_Australian_Capital_Territory ~~~ officeholder              ~~~ Andrew_Barr
# Andrew_Barr                                        ~~~ position held             ~~~ Chief_Minister_of_the_Australian_Capital_Territory
# Andrew_Barr                                        ~~~ member of political party ~~~ Australian_Labor_Party_(Australian_Capital_Territory_Branch)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The current Chief Minister of the Australian Capital Territory is Andrew Barr, who is also the leader of the Australian Labor Party.
#
#
# ============================== [Parameter config 3] Sample 1 -- ID: (35685, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# See also: Seremban Line (KTM Komuter) and Port Klang Line (KTM Komuter)
#
#
# ============================== [Parameter config 3] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Democrats for Andorra (Catalan: Demòcrates per Andorra, DA) is a centre-right political party in Andorra.
#
#
# ============================== [Parameter config 3] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born 19 March 1948 in Rome) is an Italian politician, member of the Union of the Centre.
#
#
# ============================== [Parameter config 3] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Master of the Manor and the Beautiful Kirstin (Finnish: "Kartanonherra ja kaunis Kirstin") is a novel by Kaari Utrio.
#
#
# ============================== [Parameter config 3] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Scenic Daylight was a passenger train service operated by New Zealand Railways Department (NZR) between 1960 and 1992, running from Auckland to Wellington via the North Island Main Trunk.
#
#
# ============================== [Parameter config 3] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Louis L'Amour was a prolific author of Western fiction (short stories, novels, non-fiction) and is a large part of the western genre's popularity in the latter half of the 20th century.
#
#
# ============================== [Parameter config 3] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 3] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Tome of Leo is a Christological letter sent by Pope Leo I to Flavian of Constantinople in 449, which was a central document at the Council of Chalcedon.
#
#
# ============================== [Parameter config 3] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Queensland (abbreviated as Qld) is the second-largest and third-most populous state in the Commonwealth of Australia.
#
#
# ============================== [Parameter config 3] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The genitive case (abbreviated gen; Latin: casus genitivus) is the grammatical case that marks a word, usually a noun, as modifying another word, also usually a noun—thus, indicating an attributive relationship of one noun to the other noun.
#
#
# ============================== [Parameter config 3] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 3] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini Harbour is a seaport in Mombasa, Kenya.
#
#
# ============================== [Parameter config 4] Sample 0 -- ID: (41948, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Chief_Minister_of_the_Australian_Capital_Territory ~~~ officeholder              ~~~ Andrew_Barr
# Andrew_Barr                                        ~~~ position held             ~~~ Chief_Minister_of_the_Australian_Capital_Territory
# Andrew_Barr                                        ~~~ member of political party ~~~ Australian_Labor_Party_(Australian_Capital_Territory_Branch)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The current Chief Minister is Andrew Barr of the Australian Labor Party, who was sworn in on 11 December 2014.
#
#
# ============================== [Parameter config 4] Sample 1 -- ID: (35685, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Seremban Line is a commuter rail service operated by Keretapi Tanah Melayu (KTM) in the Klang Valley, Malaysia.
#
#
# ============================== [Parameter config 4] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Democrats for Andorra (Catalan: Demòcrates per Andorra, DA) is a centre-right political party in Andorra.
#
#
# ============================== [Parameter config 4] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born in Rome, Italy) is an Italian politician and member of the Union of the Centre.
#
#
# ============================== [Parameter config 4] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra ja kaunis Kirstin (The Squire and the Beautiful Kirstin) is a novel by Kaari Utrio.
#
#
# ============================== [Parameter config 4] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Scenic Daylight was a passenger train operated by the New Zealand Railways Department (NZR) between Auckland and Wellington on the North Island Main Trunk (NIMT). It was introduced in 1960 and was the last passenger train to operate on the NIMT.
#
#
# ============================== [Parameter config 4] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) was based on the novel of the same name, and The Legend of the Golden Gun (1979) was based on the short story "The Gift of Cochise" from the collection The Sacketts.
#
#
# ============================== [Parameter config 4] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk Mazowiecki County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 4] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's Tome (also known as the Tome of Leo) is a letter written by Pope Leo I to Flavian of Constantinople in 449 AD.
#
#
# ============================== [Parameter config 4] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Queensland Government has a number of departments and agencies that are responsible for the delivery of services to the people of Queensland.
#
#
# ============================== [Parameter config 4] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The genitive case is used to indicate possession, and is also used in the formation of compound words.
#
#
# ============================== [Parameter config 4] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 4] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini Harbour is the main seaport of Mombasa, Kenya.
#
#
# ============================== [Parameter config 5] Sample 0 -- ID: (41948, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Chief_Minister_of_the_Australian_Capital_Territory ~~~ officeholder              ~~~ Andrew_Barr
# Andrew_Barr                                        ~~~ position held             ~~~ Chief_Minister_of_the_Australian_Capital_Territory
# Andrew_Barr                                        ~~~ member of political party ~~~ Australian_Labor_Party_(Australian_Capital_Territory_Branch)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The current Chief Minister is Andrew Barr of the Australian Labor Party, who was sworn in on 11 December 2014.
#
#
# ============================== [Parameter config 5] Sample 1 -- ID: (35685, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Seremban Line is a commuter rail service operated by Keretapi Tanah Melayu (KTM) in the Klang Valley, Malaysia.
#
#
# ============================== [Parameter config 5] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Democrats for Andorra (Catalan: Demòcrates per Andorra, DA) is a centre-right political party in Andorra.
#
#
# ============================== [Parameter config 5] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born in Rome, Italy) is an Italian politician and member of the Union of the Centre.
#
#
# ============================== [Parameter config 5] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra ja kaunis Kirstin (The Squire and the Beautiful Kirstin) is a novel by Kaari Utrio.
#
#
# ============================== [Parameter config 5] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Scenic Daylight was a passenger train operated by the New Zealand Railways Department (NZR) between Auckland and Wellington on the North Island Main Trunk. It was introduced in 1960, and was the first train to be given a name rather than a number.
#
#
# ============================== [Parameter config 5] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) was based on the novel of the same name, and The Legend of the Golden Gun (1979) was based on the short story "The Gift of Cochise" from the collection The Sacketts.
#
#
# ============================== [Parameter config 5] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk Mazowiecki County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 5] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's Tome (also known as the Tome of Leo) is a letter written by Pope Leo I to Flavian of Constantinople in 449 AD.
#
#
# ============================== [Parameter config 5] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Queensland Government has a number of departments and agencies that are responsible for the delivery of services to the people of Queensland.
#
#
# ============================== [Parameter config 5] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The genitive case (abbreviated gen), in grammar, is the grammatical case that marks a word, usually a noun, as modifying another word, also usually a noun.
#
#
# ============================== [Parameter config 5] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 5] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Seremban Line is a KTM Komuter train service in Malaysia that runs between Seremban and Batang Melaka.
#
#
# ============================== [Parameter config 16] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Democrats for Andorra (Demòcrates per Andorra, DA) is a centre-right political party in Andorra.
#
#
# ============================== [Parameter config 16] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born in Rome, Italy) is an Italian politician and member of the Union of the Centre.
#
#
# ============================== [Parameter config 16] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra ja kaunis Kirstin (English: "The Squire and the Beautiful Kirstin") is a novel by Kaari Utrio.
#
#
# ============================== [Parameter config 16] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Scenic Daylight was a New Zealand passenger train that ran between Auckland and Wellington from 1960 to 2001.
#
#
# ============================== [Parameter config 16] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) is a Western novel by Louis L'Amour, the third in his Sackett series.
#
#
# ============================== [Parameter config 16] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk Mazowiecki County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 16] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's Tome is a letter written by Pope Leo I to Flavian of Constantinople in 449.
#
#
# ============================== [Parameter config 16] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Australian state of Queensland has a number of national parks.
#
#
# ============================== [Parameter config 16] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The genitive case (abbreviated gen), in grammar, is the grammatical case that marks a word, usually a noun, as modifying another word, also usually a noun.
#
#
# ============================== [Parameter config 16] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 16] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini Harbour is the main seaport of Mombasa, Kenya.
#
#
# ============================== [Parameter config 17] Sample 0 -- ID: (41948, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Chief_Minister_of_the_Australian_Capital_Territory ~~~ officeholder              ~~~ Andrew_Barr
# Andrew_Barr                                        ~~~ position held             ~~~ Chief_Minister_of_the_Australian_Capital_Territory
# Andrew_Barr                                        ~~~ member of political party ~~~ Australian_Labor_Party_(Australian_Capital_Territory_Branch)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Government of the Australian Capital Territory, also referred to as the Australian Capital Territory Government or ACT Government, is the executive authority of the Australian Capital Territory, one of the territories of Australia. The leader of the party or coalition with the confidence of the Australian Capital Territory Legislative Assembly forms Government.
#
#
# ============================== [Parameter config 17] Sample 1 -- ID: (35685, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Seremban_Line ~~~ part of  ~~~ KTM_Komuter
# KTM_Komuter   ~~~ has part ~~~ Seremban_Line
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Seremban Line is a commuter rail service operated by Keretapi Tanah Melayu (KTM) in Malaysia, connecting the capital Kuala Lumpur and Seremban, the capital of Negeri Sembilan.
#
#
# ============================== [Parameter config 17] Sample 2 -- ID: (24952, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats_for_Andorra ~~~ political alignment ~~~ Centre-right_politics
# Democrats_for_Andorra ~~~ country             ~~~ Andorra
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Democrats for Andorra (Catalan: Demòcrates per Andorra, DA; Spanish: Demócratas por Andorra, DA) is a centre-right political party in Andorra.
#
#
# ============================== [Parameter config 17] Sample 3 -- ID: (36458, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario_Baccini              ~~~ place of birth         ~~~ Rome
# Mario_Baccini              ~~~ country of citizenship ~~~ Italy
# Rome                       ~~~ country                ~~~ Italy
# Union_of_the_Centre_(2002) ~~~ country                ~~~ Italy
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mario Baccini (born 30 June 1957 in Rome) is an Italian politician, leader of the Union of the Centre and member of the Chamber of Deputies.
#
#
# ============================== [Parameter config 17] Sample 4 -- ID: (55061, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra_ja_kaunis_Kirstin ~~~ author ~~~ Kaari_Utrio
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kartanonherra ja kaunis Kirstin ("The Master of the Manor and Beautiful Kirstin") is a novel by Finnish author Kaari Utrio.
#
#
# ============================== [Parameter config 17] Sample 5 -- ID: (52712, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic_Daylight         ~~~ inception ~~~ 1960
# Auckland                ~~~ country   ~~~ New_Zealand
# Wellington              ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ country   ~~~ New_Zealand
# North_Island_Main_Trunk ~~~ terminus  ~~~ Wellington
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Scenic Daylight was a passenger train operated by the New Zealand Railways Department (NZR) between Auckland and Wellington on the North Island Main Trunk from 1960 until 1964.
#
#
# ============================== [Parameter config 17] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders, a 1982 western film starring Sam Elliott, Tom Selleck, Ben Johnson and Katharine Ross, was based on two novels by Louis L'Amour – The Shadow Riders (1979) and The Sacketts (1979).
#
#
# ============================== [Parameter config 17] Sample 7 -- ID: (101285, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara_Pułapina                        ~~~ located in the administrative territorial entity ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Gmina_Baranów,_Masovian_Voivodeship   ~~~ located in the administrative territorial entity ~~~ Grodzisk_County,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ contains administrative territorial entity       ~~~ Gmina_Baranów,_Masovian_Voivodeship
# Grodzisk_County,_Masovian_Voivodeship ~~~ located in the administrative territorial entity ~~~ Masovian_Voivodeship
# Masovian_Voivodeship                  ~~~ contains administrative territorial entity       ~~~ Grodzisk_County,_Masovian_Voivodeship
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stara Pułapina is a village in the administrative district of Gmina Baranów, within Grodzisk County, Masovian Voivodeship, in east-central Poland.
#
#
# ============================== [Parameter config 17] Sample 8 -- ID: (108295, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's_Tome ~~~ author       ~~~ Pope_Leo_I
# Leo's_Tome ~~~ addressee    ~~~ Flavian_of_Constantinople
# Leo's_Tome ~~~ main subject ~~~ Christology
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Leo's Tome is the name of a letter written by Pope Leo I to Patriarch Flavian of Constantinople in 449.
#
#
# ============================== [Parameter config 17] Sample 9 -- ID: (126977, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Australia ~~~ contains administrative territorial entity ~~~ Queensland
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The State of Queensland, commonly known as Queensland, is a state in the north-east of Australia.
#
#
# ============================== [Parameter config 17] Sample 10 -- ID: (123616, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Greek_language ~~~ has grammatical case ~~~ Genitive_case
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The science became established in the 18th century as a result of Georges Cuvier's work on comparative anatomy, and developed rapidly in the 19th century. The term itself originates from Greek παλαιός, "palaios", "old, ancient", ὄν, "on" (gen. "ontos"), "being, creature", and λόγος, "logos", "speech, thought, study".
#
#
# ============================== [Parameter config 17] Sample 11 -- ID: (112276, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Texas_Tech_Red_Raiders_basketball ~~~ parent club ~~~ Texas_Tech_Red_Raiders
# Texas_Tech_Red_Raiders            ~~~ has part    ~~~ Texas_Tech_Red_Raiders_basketball
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Texas Tech Red Raiders basketball team represents Texas Tech University in Lubbock, Texas, United States in NCAA Division I men's basketball competition (the school's women's basketball team is known as the Lady Raiders).
#
#
# ============================== [Parameter config 17] Sample 12 -- ID: (132301, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini_Harbour ~~~ instance of ~~~ Port
# Kilindini_Harbour ~~~ country     ~~~ Kenya
# Mombasa           ~~~ country     ~~~ Kenya
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Kilindini Harbour, in Mombasa, Kenya, is the largest harbour in East Africa.
# {'id2idx': {(41948, 'rebel'): 0,
#   (35685, 'rebel'): 1,
#   (24952, 'rebel'): 2,
#   (36458, 'rebel'): 3,
#   (55061, 'rebel'): 4,
#   (52712, 'rebel'): 5,
#   (105540, 'rebel'): 6,
#   (101285, 'rebel'): 7,
#   (108295, 'rebel'): 8,
#   (126977, 'rebel'): 9,
#   (123616, 'rebel'): 10,
#   (112276, 'rebel'): 11,
#   (132301, 'rebel'): 12},
#  'idx2id': {0: (41948, 'rebel'),
#   1: (35685, 'rebel'),
#   2: (24952, 'rebel'),
#   3: (36458, 'rebel'),
#   4: (55061, 'rebel'),
#   5: (52712, 'rebel'),
#   6: (105540, 'rebel'),
#   7: (101285, 'rebel'),
#   8: (108295, 'rebel'),
#   9: (126977, 'rebel'),
#   10: (123616, 'rebel'),
#   11: (112276, 'rebel'),
#   12: (132301, 'rebel')}}

# %%
predictions[0]
# Out:
# {'triplet_set': [{'subject': {'name': 'Chief_Minister_of_the_Australian_Capital_Territory',
#     'qid': 'Q493649'},
#    'object': {'name': 'Andrew_Barr', 'qid': 'Q4756289'},
#    'relation': {'name': 'officeholder', 'pid': 'P1308'}},
#   {'subject': {'name': 'Andrew_Barr', 'qid': 'Q4756289'},
#    'object': {'name': 'Chief_Minister_of_the_Australian_Capital_Territory',
#     'qid': 'Q493649'},
#    'relation': {'name': 'position held', 'pid': 'P39'}},
#   {'subject': {'name': 'Andrew_Barr', 'qid': 'Q4756289'},
#    'object': {'name': 'Australian_Labor_Party_(Australian_Capital_Territory_Branch)',
#     'qid': 'Q20683858'},
#    'relation': {'name': 'member of political party', 'pid': 'P102'}}],
#  'extra-information': {'dataset-id': 41948, 'dataset': 'rebel'},
#  'prompt': 'Relations: ((Chief_Minister_of_the_Australian_Capital_Territory, appointed by, Australian_Capital_Territory_Legislative_Assembly))\nThe following sentence expresses the previous relations: The Government of the Australian Capital Territory, also referred to as the Australian Capital Territory Government or ACT Government, is the executive authority of the Australian Capital Territory, one of the territories of Australia. The leader of the party or coalition with the confidence of the Australian Capital Territory Legislative Assembly forms Government.  EOS\n\nRelations: ((Charles_Lyttelton,_10th_Viscount_Cobham, position held, Governor-General_of_New_Zealand))\nThe following sentence expresses the previous relations: It was mapped by the New Zealand Geological Survey Antarctic Expedition (1961–62) and given the family name of Charles Lyttelton, 10th Viscount Cobham, the then Governor-General of New Zealand.  EOS\n\nRelations: ((Nathan_Söderblom, position held, Archbishop_of_Uppsala))\nThe following sentence expresses the previous relations: Uppsala Domkyrkas Gosskör (the Boys\' Choir of Uppsala Cathedral) is the oldest boys\' choir in Sweden, formed in 1920. The then Archbishop of Sweden, Nathan Söderblom, had heard boys\' choirs in Germany and England and decided to institute a similar choir at Uppsala Cathedral.  EOS\n\nRelations: ((Sir_Matthew_Wood,_1st_Baronet, position held, Lord_Mayor_of_London))\nThe following sentence expresses the previous relations: Sir Matthew Wood, 1st Baronet (2 June 1768 – 25 September 1843) was a British Whig politician and was Lord Mayor of London from 1815 to 1817.  EOS\n\nRelations: ((Baji_Rao_I, position held, Peshwa))\nThe following sentence expresses the previous relations: Also close by is the historic Kashi Vishwanath Temple, the Shiva temple which has one of the 12 Jyotirlinga of India.  EOS\n\nRelations: ((Hōjō_Sadatoki, position held, Shikken), (Shikken, country, Kamakura_shogunate))\nThe following sentence expresses the previous relations: In the confusion following the quake, Hōjō Sadatoki, the Shikken of the Kamakura Shogunate, carried out a purge against his subordinate Taira no Yoritsuna.  EOS\n\nRelations: ((Françoise-Athénaïs_de_Rochechouart,_Marquise_de_Montespan, position held, Favourite))\nThe following sentence expresses the previous relations: Claude de Vin des Œillets, known as Mademoiselle des Œillets (; Provence 1637 – Paris, 18 May 1687), was a mistress of King Louis XIV of France and the companion of the official royal mistress and favourite Madame de Montespan.  EOS\n\nRelations: ((George_V, position held, Emperor_of_India))\nThe following sentence expresses the previous relations: The must see in this museum is the collection of the old manuscripts, written on palm leaves and called "olagrandhangal".  EOS\n\nRelations: ((Robert_Dundas,_2nd_Viscount_Melville, position held, First_Lord_of_the_Admiralty))\nThe following sentence expresses the previous relations: The Melville Highlands () are an ice-covered upland rising to about and forming the central part of Laurie Island between Pirie Peninsula and the south coast, in the South Orkney Islands off Antarctica. The name derives from James Weddell\'s map of 1825 whereon the name "Melville Island" appears for the already named Laurie Island; it was given for Robert Dundas, 2nd Viscount Melville, who was First Lord of the Admiralty, 1812–27 and 1828–30, including the period of Antarctic exploration by Weddell.  EOS\n\nRelations: ((Francesco_Cossiga, position held, Prime_Minister_of_Italy))\nThe following sentence expresses the previous relations: **President of the Council of Ministers: Francesco Cossiga (DC)  EOS\n\nRelations: ((Francesco_Cossiga, position held, Prime_Minister_of_Italy))\nThe following sentence expresses the previous relations: **President of the Council of Ministers: Francesco Cossiga (DC)  EOS\n\nRelations: ((Arnaldo_Forlani, position held, Prime_Minister_of_Italy))\nThe following sentence e ...
#  'model_completions': ['The Government of the Australian Capital Territory, also referred to as the Australian Capital Territory Government or ACT Government, is the executive authority of the Australian Capital Territory, one of the territories of Australia. The leader of the party or coalition with the confidence of the Australian Capital Territory Legislative Assembly forms Government.  ']}

# %%
path_to_hps_logs = "/dlabdata1/josifosk/SynthIE_main/data/hps_results/hps_synthie_small"
show_triplets = True
num_completions_to_show = 1
debug_k = None

visualize_predictions_for_experiment(path_to_hps_logs, show_triplets, num_completions_to_show, debug_k, show_api_formatted_triplets=True, show_problem=6)
# Out:
# ============================== [Parameter config 0] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In 1979, L'Amour wrote The Sacketts and The Legend of the Golden Gun, which were published posthumously.
#
#
# ============================== [Parameter config 1] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) is a Western novel by Louis L'Amour, the third in his Sackett series.
#
#
# ============================== [Parameter config 2] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun (1979)
#
#
# ============================== [Parameter config 3] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Louis L'Amour was a prolific author of Western fiction (short stories, novels, non-fiction) and is a large part of the western genre's popularity in the latter half of the 20th century.
#
#
# ============================== [Parameter config 4] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) was based on the novel of the same name, and The Legend of the Golden Gun (1979) was based on the short story "The Gift of Cochise" from the collection The Sacketts.
#
#
# ============================== [Parameter config 5] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) was based on the novel of the same name, and The Legend of the Golden Gun (1979) was based on the short story "The Gift of Cochise" from the collection The Sacketts.
#
#
# ============================== [Parameter config 6] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun (1979) was based on a story by Louis L'Amour, and The Sacketts (1979) was based on his novel of the same name.
#
#
# ============================== [Parameter config 7] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun, The Sacketts, and The Shadow Riders are based on L'Amour's novels.
#
#
# ============================== [Parameter config 8] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun (1979) and The Sacketts (1979) were written by Louis L'Amour, who also wrote the screenplay for The Shadow Riders (1982).
#
#
# ============================== [Parameter config 9] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders is a 1982 American western film directed by Andrew V. McLaglen and starring Tom Selleck, Sam Elliott, Ben Johnson, Jeff Osterhage, Glenn Ford and Katharine Ross.
#
#
# ============================== [Parameter config 10] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun (1979) The Sacketts (1979) The Shadow Riders (1982)
#
#
# ============================== [Parameter config 11] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun (1979) and The Sacketts (1979) were two television films based on Louis L'Amour's novels.
#
#
# ============================== [Parameter config 12] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) is a Western novel by Louis L'Amour.
#
#
# ============================== [Parameter config 13] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Louis L'Amour (1908–1988) was an American author of Western fiction.
#
#
# ============================== [Parameter config 14] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Louis L'Amour's The Shadow Riders and The Sacketts were published in 1979, with The Legend of the Golden Gun following in 1980.
#
#
# ============================== [Parameter config 15] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Legend of the Golden Gun (1979) and The Sacketts (1979) were two television films based on Louis L'Amour's novels.
#
#
# ============================== [Parameter config 16] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders (1982) is a Western novel by Louis L'Amour, the third in his Sackett series.
#
#
# ============================== [Parameter config 17] Sample 6 -- ID: (105540, 'rebel') ==============================
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The_Legend_of_the_Golden_Gun ~~~ publication date ~~~ 1979
# The_Sacketts                 ~~~ publication date ~~~ 1979
# The_Shadow_Riders_(film)     ~~~ screenwriter     ~~~ Louis_L'Amour
# Louis_L'Amour                ~~~ genre            ~~~ Western_(genre)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Triplets ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ("subject": The_Legend_of_the_Golden_Gun, "relation": publication date, "object": 1979) ("subject": The_Sacketts, "relation": publication date, "object": 1979) ("subject": The_Shadow_Riders_(film), "relation": screenwriter, "object": Louis_L'Amour) ("subject": Louis_L'Amour, "relation": genre, "object": Western_(genre))
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Text ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Shadow Riders, a 1982 western film starring Sam Elliott, Tom Selleck, Ben Johnson and Katharine Ross, was based on two novels by Louis L'Amour – The Shadow Riders (1979) and The Sacketts (1979).
# {'id2idx': {(41948, 'rebel'): 0,
#   (35685, 'rebel'): 1,
#   (24952, 'rebel'): 2,
#   (36458, 'rebel'): 3,
#   (55061, 'rebel'): 4,
#   (52712, 'rebel'): 5,
#   (105540, 'rebel'): 6,
#   (101285, 'rebel'): 7,
#   (108295, 'rebel'): 8,
#   (126977, 'rebel'): 9,
#   (123616, 'rebel'): 10,
#   (112276, 'rebel'): 11,
#   (132301, 'rebel'): 12},
#  'idx2id': {0: (41948, 'rebel'),
#   1: (35685, 'rebel'),
#   2: (24952, 'rebel'),
#   3: (36458, 'rebel'),
#   4: (55061, 'rebel'),
#   5: (52712, 'rebel'),
#   6: (105540, 'rebel'),
#   7: (101285, 'rebel'),
#   8: (108295, 'rebel'),
#   9: (126977, 'rebel'),
#   10: (123616, 'rebel'),
#   11: (112276, 'rebel'),
#   12: (132301, 'rebel')}}

# %%
path_to_hps_logs
# Out:
# '/dlabdata1/josifosk/SynthIE_main/data/hps_results/hps_synthie_small'

# %%
path_to_summary_file = os.path.join(path_to_hps_logs, "hps_synthie_small_results.json")
experiment_summaries = read_experiment_summaries(path_to_summary_file)

# %%
for exp_idx, exp_metadata in enumerate(experiment_summaries):
    predictions = read_predictions(os.path.join(path_to_hps_logs, exp_metadata["result_filepath"]))
    s = set([(p['extra-information']['dataset-id'], p['extra-information']['dataset']) for p in predictions])
    break

# %%
for exp_idx, exp_metadata in enumerate(experiment_summaries):
    predictions = read_predictions(os.path.join(path_to_hps_logs, exp_metadata["result_filepath"]))
    s2 = set([(p['extra-information']['dataset-id'], p['extra-information']['dataset']) for p in predictions])
    assert s == s2, exp_idx

# %%
exp_idx
# Out:
# 17
